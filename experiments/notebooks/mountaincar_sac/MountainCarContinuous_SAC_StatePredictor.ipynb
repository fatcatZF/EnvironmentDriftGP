# %%
# !pip install gpytorch
# !apt-get install swig3.0
# !ln -s /usr/bin/swig3.0 /usr/bin/swig
# !pip install gymnasium
# !pip install gymnasium[classic-control]
# !pip install stable-baselines3[extra]
# !pip install huggingface_hub
# !pip install huggingface-sb3
# !pip install river
# Out:
# Collecting gpytorch
#   Downloading gpytorch-1.12-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in /usr/local/lib/python3.10/dist-packages (from gpytorch) (1.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from gpytorch) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gpytorch) (1.13.1)
# Collecting linear-operator>=0.5.2 (from gpytorch)
#   Downloading linear_operator-0.5.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from linear-operator>=0.5.2->gpytorch) (2.3.1+cu121)
# Collecting jaxtyping>=0.2.9 (from linear-operator>=0.5.2->gpytorch)
#   Downloading jaxtyping-0.2.33-py3-none-any.whl.metadata (6.4 kB)
# Collecting typeguard~=2.13.3 (from linear-operator>=0.5.2->gpytorch)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->gpytorch) (1.26.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->gpytorch) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->gpytorch) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->linear-operator>=0.5.2->gpytorch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->linear-operator>=0.5.2->gpytorch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->linear-operator>=0.5.2->gpytorch) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->linear-operator>=0.5.2->gpytorch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->linear-operator>=0.5.2->gpytorch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->linear-operator>=0.5.2->gpytorch) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->linear-operator>=0.5.2->gpytorch) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->linear-operator>=0.5.2->gpytorch) (2.1.5)
# Downloading gpytorch-1.12-py3-none-any.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.1/274.1 kB 6.9 MB/s eta 0:00:00
# Downloading linear_operator-0.5.2-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.6/175.6 kB 6.4 MB/s eta 0:00:00
# Downloading jaxtyping-0.2.33-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 1.3 MB/s eta 0:00:00
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 12.4 MB/s eta 0:00:00
# Installing collected packages: typeguard, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jaxtyping, nvidia-cusolver-cu12, linear-operator, gpytorch
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.3.0
#     Uninstalling typeguard-4.3.0:
#       Successfully uninstalled typeguard-4.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# inflect 7.3.1 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed gpytorch-1.12 jaxtyping-0.2.33 linear-operator-0.5.2 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 typeguard-2.13.3
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   swig3.0-examples swig3.0-doc
# The following NEW packages will be installed:
#   swig3.0
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 1,109 kB of archives.
# After this operation, 5,555 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig3.0 amd64 3.0.12-2.2ubuntu1 [1,109 kB]
# Fetched 1,109 kB in 1s (1,530 kB/s)
# Selecting previously unselected package swig3.0.
# (Reading database ... 123588 files and directories currently installed.)
# Preparing to unpack .../swig3.0_3.0.12-2.2ubuntu1_amd64.deb ...
# Unpacking swig3.0 (3.0.12-2.2ubuntu1) ...
# Setting up swig3.0 (3.0.12-2.2ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting gymnasium
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 22.6 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1
# Requirement already satisfied: gymnasium[classic-control] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]) (2.6.0)
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-2.3.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.3.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.1.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.6.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.17.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.66.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (13.7.1)
# Collecting shimmy~=1.3.0 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra])
#   Downloading Shimmy-1.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (9.4.0)
# Collecting autorom~=0.6.1 (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.31.0)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 11.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra])
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (71.0.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3[extra]) (12.5.82)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (2.16.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (6.4.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Downloading stable_baselines3-2.3.2-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 11.4 MB/s eta 0:00:00
# Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 42.9 MB/s eta 0:00:00
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446662 sha256=6c3a67167ac9b5fbbcabaf8cc6a44b098b2aea5c6f9d5d058203ddaa21bc269c
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: ale-py, shimmy, AutoROM.accept-rom-license, autorom, stable-baselines3
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 shimmy-1.3.0 stable-baselines3-2.3.2
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.23.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.7.4)
# Collecting huggingface-sb3
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3) (0.23.5)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3) (6.0.1)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3) (1.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.6 in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3) (2.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3) (2024.7.4)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Installing collected packages: huggingface-sb3
# Successfully installed huggingface-sb3-3.0
# Collecting river
#   Downloading river-0.21.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from river) (1.26.4)
# Requirement already satisfied: pandas<3.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from river) (2.1.4)
# Requirement already satisfied: scipy<2.0.0,>=1.12.1 in /usr/local/lib/python3.10/dist-packages (from river) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=2.1->river) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=2.1->river) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=2.1->river) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=2.1->river) (1.16.0)
# Downloading river-0.21.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 46.9 MB/s eta 0:00:00
# Installing collected packages: river
# Successfully installed river-0.21.2

# %%
import numpy as np
import pandas as pd

import pickle

import math

import gymnasium as gym
from gym.envs.classic_control.continuous_mountain_car import Continuous_MountainCarEnv
from gymnasium.wrappers import TransformReward, TransformObservation

from sklearn.metrics import mean_squared_error as mse
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

import scipy
from scipy.stats import norm
from scipy.special import logsumexp

import gpytorch
import torch
from torch.optim.lr_scheduler import ExponentialLR
from torch.utils.data import TensorDataset, DataLoader
import gpytorch
from gpytorch.models import ApproximateGP
from gpytorch.variational import CholeskyVariationalDistribution
from gpytorch.variational import VariationalStrategy

from huggingface_sb3 import load_from_hub
from stable_baselines3 import SAC
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import is_wrapped

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, PillowWriter
from matplotlib.colors import LogNorm

import scipy
from scipy.stats import multivariate_normal

from collections import deque
from typing import Optional, Tuple

from river import drift
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Device

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %% [markdown]
# ## Create Drifted Environment Class

# %%
class Continuous_MountainCarEnvWithWind(Continuous_MountainCarEnv):
  def __init__(self, render_mode: Optional[str] = None, goal_velocity=0, wind_direction="left",
               windpower=0.35):
    super().__init__(render_mode, goal_velocity)
    self.wind_direction = wind_direction
    self.windpower = windpower

  def step(self, action: np.ndarray):
        position = self.state[0]
        velocity = self.state[1]
        force = min(max(action[0], self.min_action), self.max_action)

        windforce = max(np.random.normal(self.windpower, 0.015),0.)

        #velocity += force * self.power - 0.0025 * math.cos(3 * position)

        if self.wind_direction == "left":
          # Left Wind
          velocity += (force-windforce) * self.power - 0.0025 * math.cos(3 * position)
        else:
          # Right Wind
          velocity += (force+windforce) * self.power - 0.0025 * math.cos(3 * position)


        if velocity > self.max_speed:
            velocity = self.max_speed
        if velocity < -self.max_speed:
            velocity = -self.max_speed
        position += velocity
        if position > self.max_position:
            position = self.max_position
        if position < self.min_position:
            position = self.min_position
        if position == self.min_position and velocity < 0:
            velocity = 0

        # Convert a possible numpy bool to a Python bool.
        terminated = bool(
            position >= self.goal_position and velocity >= self.goal_velocity
        )

        reward = 0
        if terminated:
            reward = 100.0
        reward -= math.pow(action[0], 2) * 0.1

        self.state = np.array([position, velocity], dtype=np.float32)

        if self.render_mode == "human":
            self.render()
        # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
        return self.state, reward, terminated, False, {}

# %% [markdown]
# ## Load Trained Policy from HuggingFace

# %%
checkpoint = load_from_hub(
    repo_id = "sb3/sac-MountainCarContinuous-v0",
    filename = "sac-MountainCarContinuous-v0.zip",
)

model = SAC.load(checkpoint)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# sac-MountainCarContinuous-v0.zip:   0%|          | 0.00/238k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/save_util.py:167: UserWarning: Could not deserialize object learning_rate. Consider using `custom_objects` argument to replace this object.
# Exception: 'bytes' object cannot be interpreted as an integer
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/save_util.py:167: UserWarning: Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: 'bytes' object cannot be interpreted as an integer
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(

# %% [markdown]
# ## Train SVGP StatePredictor on Training Environment

# %%
env0 = Continuous_MountainCarEnv()
env0.reset()
# Out:
# array([-0.46389887,  0.        ], dtype=float32)

# %%
observations = []
actions = []
rewards = []
dones = []
sources = []
targets = []

obs_t = env0.reset()
observations.append(obs_t)

for i in range(20000):
  action_t, _state = model.predict(obs_t, deterministic=True)
  actions.append(action_t)
  obs_tplus1, r_tplus1, terminated, truncated, info = env0.step(action_t)

  done = terminated or truncated
  dones.append(done)

  observations.append(obs_tplus1)
  rewards.append(r_tplus1)
  sources.append(np.concatenate([obs_t, action_t]))
  targets.append(obs_tplus1-obs_t)

  obs_t = obs_tplus1

  if done:
    obs_t = env0.reset()

sources = np.array(sources)
targets = np.array(targets)

n_train = int(len(sources)*0.8)

# %%
X_train_env0, X_test_env0, y_train_env0, y_test_env0 = sources[:n_train], sources[n_train:], targets[:n_train],  targets[n_train:]

scaler = StandardScaler()
scaler.fit(X_train_env0)
X_train_env0_scaled = scaler.transform(X_train_env0)
X_test_env0_scaled = scaler.transform(X_test_env0)

# get the number of tasks (the prediction dimensions)
n_tasks = y_train_env0.shape[-1]

# Compute inducing points
n_inducing = 100
kmeans = KMeans(n_clusters=n_inducing).fit(X_train_env0_scaled)
inducing_points = kmeans.cluster_centers_
inducing_points = torch.from_numpy(inducing_points.astype(np.float32))
inducing_points = torch.concat([inducing_points]*n_tasks, dim=0)
inducing_points = inducing_points.reshape(n_tasks, n_inducing, -1)

X_train_env0_tensor = torch.from_numpy(X_train_env0_scaled).contiguous().to(device)
X_test_env0_tensor = torch.from_numpy(X_test_env0_scaled).contiguous().to(device)
y_train_env0_tensor = torch.from_numpy(y_train_env0).contiguous().to(device)
y_test_env0_tensor = torch.from_numpy(y_test_env0).contiguous().to(device)


train_dataset = TensorDataset(X_train_env0_tensor, y_train_env0_tensor)
train_loader = DataLoader(train_dataset, batch_size=800, shuffle=True)
test_dataset = TensorDataset(X_test_env0_tensor, y_test_env0_tensor)
test_loader = DataLoader(test_dataset, batch_size=800, shuffle=False)

class StatePredictor(ApproximateGP):
  def __init__(self, inducing_points):
    inducing_points = inducing_points
    variational_distribution = CholeskyVariationalDistribution(inducing_points.size(-2),
                                                               batch_shape=torch.Size([n_tasks]))

    variational_strategy = gpytorch.variational.IndependentMultitaskVariationalStrategy(
                                                   VariationalStrategy(self, inducing_points,
                                                       variational_distribution,
                                                       learn_inducing_locations=True),
                                                num_tasks=n_tasks
                                             )

    super(StatePredictor, self).__init__(variational_strategy)
    self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([n_tasks]))
    self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel(batch_shape=torch.Size([n_tasks]),
                                                                                ard_num_dims=X_train_env0_tensor.size(-1)),
                                                    batch_shape = torch.Size([n_tasks])
                                                  )

  def forward(self, x):
    mean_x = self.mean_module(x)
    covar_x = self.covar_module(x)
    return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

model_gp_env0 = StatePredictor(inducing_points)
likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=n_tasks)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
num_epochs = 3000


model_gp_env0 = model_gp_env0.to(device)
likelihood = likelihood.to(device)

model_gp_env0.train()
likelihood.train()

optimizer = torch.optim.Adam([
    {"params": model_gp_env0.parameters()},
    {"params": likelihood.parameters()},
], lr=0.05)

#scheduler = MultiStepLR(optimizer, milestones=[500, 1000, 1500], gamma=0.5)
scheduler = ExponentialLR(optimizer, gamma=1-1e-3)

# loss object: VariationalELBO
mll = gpytorch.mlls.VariationalELBO(likelihood, model_gp_env0,
                                    num_data=y_train_env0_tensor.size(0))


best_loss_test = np.inf
losses_train = []
losses_test = []
#epochs_iter = tqdm.notebook.tqdm(range(num_epochs), desc="Epoch")
for i in range(num_epochs):
  model_gp_env0.train()
  likelihood.train()
  for _, (x_batch, y_batch) in enumerate(train_loader):
    x_batch = x_batch.to(device)
    y_batch = y_batch.to(device)
    optimizer.zero_grad()
    output = model_gp_env0(x_batch)
    loss = -mll(output, y_batch)
    loss.backward()
    optimizer.step()
    scheduler.step()
    losses_train.append(loss.item())


  with torch.no_grad():
    model_gp_env0.eval()
    likelihood.eval()
    for _, (x_batch, y_batch) in enumerate(test_loader):
      x_batch = x_batch.to(device)
      y_batch = y_batch.to(device)
      output = model_gp_env0(x_batch)
      loss = -mll(output, y_batch)
      losses_test.append(loss.item())
  print(f"""Iteration: {i+1}, train loss: {np.mean(losses_train)},
                     test loss: {np.mean(losses_test)}""")

  if np.mean(losses_test) < best_loss_test:
      torch.save(model_gp_env0, "model_gp_env0.pth")
      best_loss_test = np.mean(losses_test)
      print("Best model so far!")
# Out:
# Streaming output truncated to the last 5000 lines.
#                      test loss: -6.1176406967720345
# Best model so far!
# Iteration: 1335, train loss: -6.111083180184584,
#                      test loss: -6.117662967666704
# Best model so far!
# Iteration: 1336, train loss: -6.111107870779268,
#                      test loss: -6.117685205221711
# Best model so far!
# Iteration: 1337, train loss: -6.1111325243682995,
#                      test loss: -6.117707409511865
# Best model so far!
# Iteration: 1338, train loss: -6.111157141123747,
#                      test loss: -6.117729580611748
# Best model so far!
# Iteration: 1339, train loss: -6.111181721128134,
#                      test loss: -6.117751718595724
# Best model so far!
# Iteration: 1340, train loss: -6.11120626439257,
#                      test loss: -6.1177738235379335
# Best model so far!
# Iteration: 1341, train loss: -6.111230771070364,
#                      test loss: -6.117795895512295
# Best model so far!
# Iteration: 1342, train loss: -6.111255241190007,
#                      test loss: -6.117817934592506
# Best model so far!
# Iteration: 1343, train loss: -6.111279674992936,
#                      test loss: -6.117839940852047
# Best model so far!
# Iteration: 1344, train loss: -6.111304072347342,
#                      test loss: -6.117861914364178
# Best model so far!
# Iteration: 1345, train loss: -6.11132843349406,
#                      test loss: -6.117883855201941
# Best model so far!
# Iteration: 1346, train loss: -6.111352758336658,
#                      test loss: -6.117905763438163
# Best model so far!
# Iteration: 1347, train loss: -6.111377047186091,
#                      test loss: -6.117927639145451
# Best model so far!
# Iteration: 1348, train loss: -6.111401299910222,
#                      test loss: -6.117949482396201
# Best model so far!
# Iteration: 1349, train loss: -6.111425516607062,
#                      test loss: -6.117971293262591
# Best model so far!
# Iteration: 1350, train loss: -6.111449697515617,
#                      test loss: -6.117993071816586
# Best model so far!
# Iteration: 1351, train loss: -6.111473842662416,
#                      test loss: -6.1180148181299385
# Best model so far!
# Iteration: 1352, train loss: -6.111497952056272,
#                      test loss: -6.118036532274188
# Best model so far!
# Iteration: 1353, train loss: -6.111522025794082,
#                      test loss: -6.118058214320664
# Best model so far!
# Iteration: 1354, train loss: -6.111546063919633,
#                      test loss: -6.1180798643404835
# Best model so far!
# Iteration: 1355, train loss: -6.111570066705319,
#                      test loss: -6.118101482404554
# Best model so far!
# Iteration: 1356, train loss: -6.111594034053501,
#                      test loss: -6.118123068583574
# Best model so far!
# Iteration: 1357, train loss: -6.111617966112801,
#                      test loss: -6.1181446229480345
# Best model so far!
# Iteration: 1358, train loss: -6.111641862873394,
#                      test loss: -6.118166145568217
# Best model so far!
# Iteration: 1359, train loss: -6.111665724448289,
#                      test loss: -6.118187636514198
# Best model so far!
# Iteration: 1360, train loss: -6.111689550897572,
#                      test loss: -6.118209095855846
# Best model so far!
# Iteration: 1361, train loss: -6.111713342456329,
#                      test loss: -6.1182305236628265
# Best model so far!
# Iteration: 1362, train loss: -6.111737098973846,
#                      test loss: -6.118251920004599
# Best model so far!
# Iteration: 1363, train loss: -6.111760820719664,
#                      test loss: -6.118273284950417
# Best model so far!
# Iteration: 1364, train loss: -6.111784507700343,
#                      test loss: -6.118294618569337
# Best model so far!
# Iteration: 1365, train loss: -6.111808159939891,
#                      test loss: -6.118315920930206
# Best model so far!
# Iteration: 1366, train loss: -6.1118317775495115,
#                      test loss: -6.1183371921016745
# Best model so far!
# Iteration: 1367, train loss: -6.111855360622645,
#                      test loss: -6.118358432152189
# Best model so far!
# Iteration: 1368, train loss: -6.111878909113033,
#                      test loss: -6.118379641149999
# Best model so far!
# Iteration: 1369, train loss: -6.111902423148704,
#                      test loss: -6.118400819163152
# Best model so far!
# Iteration: 1370, train loss: -6.111925902961733,
#                      test loss: -6.118421966259497
# Best model so far!
# Iteration: 1371, train loss: -6.111949348522664,
#                      test loss: -6.118443082506686
# Best model so far!
# Iteration: 1372, train loss: -6.111972759975902,
#                      test loss: -6.118464167972174
# Best model so far!
# Iteration: 1373, train loss: -6.111996137170231,
#                      test loss: -6.118485222723218
# Best model so far!
# Iteration: 1374, train loss: -6.112019480423381,
#                      test loss: -6.118506246826882
# Best model so far!
# Iteration: 1375, train loss: -6.112042789774727,
#                      test loss: -6.11852724035003
# Best model so far!
# Iteration: 1376, train loss: -6.112066065159567,
#                      test loss: -6.118548203359336
# Best model so far!
# Iteration: 1377, train loss: -6.112089306807731,
#                      test loss: -6.11856913592128
# Best model so far!
# Iteration: 1378, train loss: -6.112112514619649,
#                      test loss: -6.118590038102147
# Best model so far!
# Iteration: 1379, train loss: -6.112135688720799,
#                      test loss: -6.118610909968031
# Best model so far!
# Iteration: 1380, train loss: -6.112158829409062,
#                      test loss: -6.118631751584834
# Best model so far!
# Iteration: 1381, train loss: -6.112181936480796,
#                      test loss: -6.118652563018267
# Best model so far!
# Iteration: 1382, train loss: -6.11220501007798,
#                      test loss: -6.1186733443338515
# Best model so far!
# Iteration: 1383, train loss: -6.112228050273227,
#                      test loss: -6.118694095596919
# Best model so far!
# Iteration: 1384, train loss: -6.112251057276755,
#                      test loss: -6.118714816872612
# Best model so far!
# Iteration: 1385, train loss: -6.112274031074388,
#                      test loss: -6.118735508225885
# Best model so far!
# Iteration: 1386, train loss: -6.112296971720798,
#                      test loss: -6.118756169721506
# Best model so far!
# Iteration: 1387, train loss: -6.112319879304878,
#                      test loss: -6.118776801424054
# Best model so far!
# Iteration: 1388, train loss: -6.112342753846558,
#                      test loss: -6.118797403397925
# Best model so far!
# Iteration: 1389, train loss: -6.112365595417203,
#                      test loss: -6.1188179757073256
# Best model so far!
# Iteration: 1390, train loss: -6.112388404190889,
#                      test loss: -6.118838518416281
# Best model so far!
# Iteration: 1391, train loss: -6.112411180169788,
#                      test loss: -6.118859031588632
# Best model so far!
# Iteration: 1392, train loss: -6.112433923321814,
#                      test loss: -6.118879515288033
# Best model so far!
# Iteration: 1393, train loss: -6.112456633957278,
#                      test loss: -6.118899969577961
# Best model so far!
# Iteration: 1394, train loss: -6.112479311975128,
#                      test loss: -6.118920394521703
# Best model so far!
# Iteration: 1395, train loss: -6.112501957496781,
#                      test loss: -6.118940790182373
# Best model so far!
# Iteration: 1396, train loss: -6.1125245705237585,
#                      test loss: -6.118961156622899
# Best model so far!
# Iteration: 1397, train loss: -6.112547151142906,
#                      test loss: -6.11898149390603
# Best model so far!
# Iteration: 1398, train loss: -6.1125696995260945,
#                      test loss: -6.119001802094334
# Best model so far!
# Iteration: 1399, train loss: -6.1125922156401975,
#                      test loss: -6.119022081250204
# Best model so far!
# Iteration: 1400, train loss: -6.112614699588423,
#                      test loss: -6.119042331435851
# Best model so far!
# Iteration: 1401, train loss: -6.1126371514736855,
#                      test loss: -6.119062552713309
# Best model so far!
# Iteration: 1402, train loss: -6.11265957133058,
#                      test loss: -6.119082745144438
# Best model so far!
# Iteration: 1403, train loss: -6.112681959227593,
#                      test loss: -6.119102908790919
# Best model so far!
# Iteration: 1404, train loss: -6.112704315283959,
#                      test loss: -6.119123043714255
# Best model so far!
# Iteration: 1405, train loss: -6.112726639364034,
#                      test loss: -6.1191431499757805
# Best model so far!
# Iteration: 1406, train loss: -6.1127489317395325,
#                      test loss: -6.119163227636648
# Best model so far!
# Iteration: 1407, train loss: -6.112771192495,
#                      test loss: -6.119183276757841
# Best model so far!
# Iteration: 1408, train loss: -6.112793421528477,
#                      test loss: -6.11920329740017
# Best model so far!
# Iteration: 1409, train loss: -6.112815619009032,
#                      test loss: -6.119223289624269
# Best model so far!
# Iteration: 1410, train loss: -6.1128377849868905,
#                      test loss: -6.119243253490604
# Best model so far!
# Iteration: 1411, train loss: -6.112859919579722,
#                      test loss: -6.119263189059466
# Best model so far!
# Iteration: 1412, train loss: -6.112882022786669,
#                      test loss: -6.11928309639098
# Best model so far!
# Iteration: 1413, train loss: -6.112904094741861,
#                      test loss: -6.119302975545095
# Best model so far!
# Iteration: 1414, train loss: -6.112926135511603,
#                      test loss: -6.119322826581595
# Best model so far!
# Iteration: 1415, train loss: -6.1129481450609156,
#                      test loss: -6.119342649560092
# Best model so far!
# Iteration: 1416, train loss: -6.112970123657994,
#                      test loss: -6.119362444540033
# Best model so far!
# Iteration: 1417, train loss: -6.11299207128424,
#                      test loss: -6.119382211580694
# Best model so far!
# Iteration: 1418, train loss: -6.113013987937924,
#                      test loss: -6.119401950741184
# Best model so far!
# Iteration: 1419, train loss: -6.113035873617318,
#                      test loss: -6.119421662080447
# Best model so far!
# Iteration: 1420, train loss: -6.113057728404652,
#                      test loss: -6.119441345657261
# Best model so far!
# Iteration: 1421, train loss: -6.11307955258326,
#                      test loss: -6.1194610015302375
# Best model so far!
# Iteration: 1422, train loss: -6.113101345966223,
#                      test loss: -6.119480629757822
# Best model so far!
# Iteration: 1423, train loss: -6.1131231087357465,
#                      test loss: -6.119500230398299
# Best model so far!
# Iteration: 1424, train loss: -6.11314484092284,
#                      test loss: -6.119519803509786
# Best model so far!
# Iteration: 1425, train loss: -6.113166542575155,
#                      test loss: -6.119539349150239
# Best model so far!
# Iteration: 1426, train loss: -6.11318821382381,
#                      test loss: -6.119558867377452
# Best model so far!
# Iteration: 1427, train loss: -6.113209854649183,
#                      test loss: -6.119578358249056
# Best model so far!
# Iteration: 1428, train loss: -6.11323146514858,
#                      test loss: -6.11959782182252
# Best model so far!
# Iteration: 1429, train loss: -6.113253045485774,
#                      test loss: -6.119617258155154
# Best model so far!
# Iteration: 1430, train loss: -6.113274595640678,
#                      test loss: -6.119636667304106
# Best model so far!
# Iteration: 1431, train loss: -6.113296115659907,
#                      test loss: -6.119656049326364
# Best model so far!
# Iteration: 1432, train loss: -6.1133176056398915,
#                      test loss: -6.119675404278759
# Best model so far!
# Iteration: 1433, train loss: -6.113339065593607,
#                      test loss: -6.119694732217962
# Best model so far!
# Iteration: 1434, train loss: -6.113360495600496,
#                      test loss: -6.119714033200485
# Best model so far!
# Iteration: 1435, train loss: -6.113381895773009,
#                      test loss: -6.119733307282684
# Best model so far!
# Iteration: 1436, train loss: -6.113403266073855,
#                      test loss: -6.119752554520757
# Best model so far!
# Iteration: 1437, train loss: -6.113424606797679,
#                      test loss: -6.119771774970747
# Best model so far!
# Iteration: 1438, train loss: -6.1134459178901235,
#                      test loss: -6.119790968688539
# Best model so far!
# Iteration: 1439, train loss: -6.113467199230713,
#                      test loss: -6.119810135729865
# Best model so far!
# Iteration: 1440, train loss: -6.113488450964215,
#                      test loss: -6.119829276150299
# Best model so far!
# Iteration: 1441, train loss: -6.11350967335081,
#                      test loss: -6.119848390005266
# Best model so far!
# Iteration: 1442, train loss: -6.113530866220082,
#                      test loss: -6.11986747735003
# Best model so far!
# Iteration: 1443, train loss: -6.113552029682962,
#                      test loss: -6.119886538239708
# Best model so far!
# Iteration: 1444, train loss: -6.113573163833567,
#                      test loss: -6.119905572729262
# Best model so far!
# Iteration: 1445, train loss: -6.113594268633755,
#                      test loss: -6.119924580873502
# Best model so far!
# Iteration: 1446, train loss: -6.1136153443093,
#                      test loss: -6.119943562727086
# Best model so far!
# Iteration: 1447, train loss: -6.113636390920587,
#                      test loss: -6.119962518344522
# Best model so far!
# Iteration: 1448, train loss: -6.113657408461968,
#                      test loss: -6.119981447780165
# Best model so far!
# Iteration: 1449, train loss: -6.113678396960721,
#                      test loss: -6.1200003510882235
# Best model so far!
# Iteration: 1450, train loss: -6.1136993565920354,
#                      test loss: -6.120019228322753
# Best model so far!
# Iteration: 1451, train loss: -6.1137202872019865,
#                      test loss: -6.120038079537662
# Best model so far!
# Iteration: 1452, train loss: -6.113741188998316,
#                      test loss: -6.12005690478671
# Best model so far!
# Iteration: 1453, train loss: -6.113762061974881,
#                      test loss: -6.12007570412351
# Best model so far!
# Iteration: 1454, train loss: -6.113782906305926,
#                      test loss: -6.120094477601524
# Best model so far!
# Iteration: 1455, train loss: -6.113803722001356,
#                      test loss: -6.1201132252740695
# Best model so far!
# Iteration: 1456, train loss: -6.113824509120173,
#                      test loss: -6.120131947194318
# Best model so far!
# Iteration: 1457, train loss: -6.113845267639397,
#                      test loss: -6.120150643415294
# Best model so far!
# Iteration: 1458, train loss: -6.113865997797754,
#                      test loss: -6.120169313989876
# Best model so far!
# Iteration: 1459, train loss: -6.113886699473806,
#                      test loss: -6.120187958970798
# Best model so far!
# Iteration: 1460, train loss: -6.113907372873046,
#                      test loss: -6.120206578410651
# Best model so far!
# Iteration: 1461, train loss: -6.113928017890353,
#                      test loss: -6.120225172361881
# Best model so far!
# Iteration: 1462, train loss: -6.113948634681808,
#                      test loss: -6.120243740876788
# Best model so far!
# Iteration: 1463, train loss: -6.113969223288996,
#                      test loss: -6.120262284007532
# Best model so far!
# Iteration: 1464, train loss: -6.113989783785957,
#                      test loss: -6.120280801806131
# Best model so far!
# Iteration: 1465, train loss: -6.114010316132609,
#                      test loss: -6.120299294324458
# Best model so far!
# Iteration: 1466, train loss: -6.114030820484137,
#                      test loss: -6.120317761614248
# Best model so far!
# Iteration: 1467, train loss: -6.1140512969628,
#                      test loss: -6.120336203727091
# Best model so far!
# Iteration: 1468, train loss: -6.114071745593075,
#                      test loss: -6.120354620714441
# Best model so far!
# Iteration: 1469, train loss: -6.114092166237077,
#                      test loss: -6.120373012627607
# Best model so far!
# Iteration: 1470, train loss: -6.114112559195203,
#                      test loss: -6.120391379517763
# Best model so far!
# Iteration: 1471, train loss: -6.114132924442877,
#                      test loss: -6.12040972143594
# Best model so far!
# Iteration: 1472, train loss: -6.11415326200418,
#                      test loss: -6.120428038433032
# Best model so far!
# Iteration: 1473, train loss: -6.114173571854572,
#                      test loss: -6.120446330559796
# Best model so far!
# Iteration: 1474, train loss: -6.114193854163675,
#                      test loss: -6.120464597866849
# Best model so far!
# Iteration: 1475, train loss: -6.1142141090198345,
#                      test loss: -6.120482840404672
# Best model so far!
# Iteration: 1476, train loss: -6.114234336462695,
#                      test loss: -6.120501058223609
# Best model so far!
# Iteration: 1477, train loss: -6.1142545365479375,
#                      test loss: -6.120519251373868
# Best model so far!
# Iteration: 1478, train loss: -6.114274709234304,
#                      test loss: -6.120537419905521
# Best model so far!
# Iteration: 1479, train loss: -6.114294854609612,
#                      test loss: -6.1205555638685025
# Best model so far!
# Iteration: 1480, train loss: -6.114314972729221,
#                      test loss: -6.120573683312616
# Best model so far!
# Iteration: 1481, train loss: -6.114335063551751,
#                      test loss: -6.120591778287527
# Best model so far!
# Iteration: 1482, train loss: -6.114355127405949,
#                      test loss: -6.1206098488427685
# Best model so far!
# Iteration: 1483, train loss: -6.114375164233832,
#                      test loss: -6.120627895027741
# Best model so far!
# Iteration: 1484, train loss: -6.114395174106101,
#                      test loss: -6.120645916891709
# Best model so far!
# Iteration: 1485, train loss: -6.114415156932717,
#                      test loss: -6.1206639144838055
# Best model so far!
# Iteration: 1486, train loss: -6.1144351128805905,
#                      test loss: -6.120681887853033
# Best model so far!
# Iteration: 1487, train loss: -6.114455042068083,
#                      test loss: -6.12069983704826
# Best model so far!
# Iteration: 1488, train loss: -6.114474944356874,
#                      test loss: -6.120717762118225
# Best model so far!
# Iteration: 1489, train loss: -6.114494820073362,
#                      test loss: -6.120735663111535
# Best model so far!
# Iteration: 1490, train loss: -6.114514669063032,
#                      test loss: -6.120753540076666
# Best model so far!
# Iteration: 1491, train loss: -6.114534491427633,
#                      test loss: -6.120771393061964
# Best model so far!
# Iteration: 1492, train loss: -6.11455428710884,
#                      test loss: -6.120789222115646
# Best model so far!
# Iteration: 1493, train loss: -6.114574056335932,
#                      test loss: -6.1208070272858
# Best model so far!
# Iteration: 1494, train loss: -6.114593799082236,
#                      test loss: -6.120824808620386
# Best model so far!
# Iteration: 1495, train loss: -6.114613515416839,
#                      test loss: -6.120842566167232
# Best model so far!
# Iteration: 1496, train loss: -6.114633205392707,
#                      test loss: -6.1208602999740425
# Best model so far!
# Iteration: 1497, train loss: -6.1146528690467346,
#                      test loss: -6.120878010088393
# Best model so far!
# Iteration: 1498, train loss: -6.114672506479385,
#                      test loss: -6.12089569655773
# Best model so far!
# Iteration: 1499, train loss: -6.114692117743134,
#                      test loss: -6.120913359429377
# Best model so far!
# Iteration: 1500, train loss: -6.114711702810848,
#                      test loss: -6.120930998750528
# Best model so far!
# Iteration: 1501, train loss: -6.114731261830189,
#                      test loss: -6.120948614568253
# Best model so far!
# Iteration: 1502, train loss: -6.114750794805562,
#                      test loss: -6.120966206929497
# Best model so far!
# Iteration: 1503, train loss: -6.114770301788951,
#                      test loss: -6.1209837758810774
# Best model so far!
# Iteration: 1504, train loss: -6.114789782752942,
#                      test loss: -6.1210013214696914
# Best model so far!
# Iteration: 1505, train loss: -6.114809237955343,
#                      test loss: -6.121018843741908
# Best model so far!
# Iteration: 1506, train loss: -6.114828667304989,
#                      test loss: -6.121036342744175
# Best model so far!
# Iteration: 1507, train loss: -6.114848070821707,
#                      test loss: -6.121053818522816
# Best model so far!
# Iteration: 1508, train loss: -6.114867448588507,
#                      test loss: -6.121071271124031
# Best model so far!
# Iteration: 1509, train loss: -6.114886800672383,
#                      test loss: -6.1210887005939005
# Best model so far!
# Iteration: 1510, train loss: -6.114906127061201,
#                      test loss: -6.121106106978378
# Best model so far!
# Iteration: 1511, train loss: -6.114925427995327,
#                      test loss: -6.121123490323301
# Best model so far!
# Iteration: 1512, train loss: -6.114944703367578,
#                      test loss: -6.12114085067438
# Best model so far!
# Iteration: 1513, train loss: -6.114963953212883,
#                      test loss: -6.121158188077211
# Best model so far!
# Iteration: 1514, train loss: -6.114983177534581,
#                      test loss: -6.1211755025772625
# Best model so far!
# Iteration: 1515, train loss: -6.115002376650746,
#                      test loss: -6.121192794219889
# Best model so far!
# Iteration: 1516, train loss: -6.115021550265266,
#                      test loss: -6.121210063050322
# Best model so far!
# Iteration: 1517, train loss: -6.115040698680037,
#                      test loss: -6.121227309113674
# Best model so far!
# Iteration: 1518, train loss: -6.115059821960567,
#                      test loss: -6.1212445324549405
# Best model so far!
# Iteration: 1519, train loss: -6.115078920078016,
#                      test loss: -6.121261733118996
# Best model so far!
# Iteration: 1520, train loss: -6.115097993050678,
#                      test loss: -6.1212789111506
# Best model so far!
# Iteration: 1521, train loss: -6.115117040912472,
#                      test loss: -6.1212960665943905
# Best model so far!
# Iteration: 1522, train loss: -6.1151360638382135,
#                      test loss: -6.121313199494891
# Best model so far!
# Iteration: 1523, train loss: -6.115155061704821,
#                      test loss: -6.121330309896507
# Best model so far!
# Iteration: 1524, train loss: -6.1151740346867784,
#                      test loss: -6.121347397843527
# Best model so far!
# Iteration: 1525, train loss: -6.115192982770503,
#                      test loss: -6.121364463380126
# Best model so far!
# Iteration: 1526, train loss: -6.11521190595807,
#                      test loss: -6.1213815065503585
# Best model so far!
# Iteration: 1527, train loss: -6.115230804360847,
#                      test loss: -6.121398527398169
# Best model so far!
# Iteration: 1528, train loss: -6.115249678074305,
#                      test loss: -6.121415525967382
# Best model so far!
# Iteration: 1529, train loss: -6.115268527037733,
#                      test loss: -6.121432502301711
# Best model so far!
# Iteration: 1530, train loss: -6.115287351330828,
#                      test loss: -6.121449456444752
# Best model so far!
# Iteration: 1531, train loss: -6.115306150986357,
#                      test loss: -6.121466388439992
# Best model so far!
# Iteration: 1532, train loss: -6.115324926254882,
#                      test loss: -6.121483298330799
# Best model so far!
# Iteration: 1533, train loss: -6.115343676919734,
#                      test loss: -6.12150018616043
# Best model so far!
# Iteration: 1534, train loss: -6.1153624031378255,
#                      test loss: -6.121517051972031
# Best model so far!
# Iteration: 1535, train loss: -6.115381104972468,
#                      test loss: -6.121533895808633
# Best model so far!
# Iteration: 1536, train loss: -6.11539978242472,
#                      test loss: -6.1215507177131565
# Best model so far!
# Iteration: 1537, train loss: -6.115418435666267,
#                      test loss: -6.121567517728408
# Best model so far!
# Iteration: 1538, train loss: -6.115437064666824,
#                      test loss: -6.121584295897087
# Best model so far!
# Iteration: 1539, train loss: -6.115455669489138,
#                      test loss: -6.121601052261777
# Best model so far!
# Iteration: 1540, train loss: -6.115474250118381,
#                      test loss: -6.121617786864956
# Best model so far!
# Iteration: 1541, train loss: -6.115492806555238,
#                      test loss: -6.121634499748986
# Best model so far!
# Iteration: 1542, train loss: -6.115511338908622,
#                      test loss: -6.121651190956125
# Best model so far!
# Iteration: 1543, train loss: -6.1155298472871635,
#                      test loss: -6.1216678605285155
# Best model so far!
# Iteration: 1544, train loss: -6.115548331706563,
#                      test loss: -6.121684508508197
# Best model so far!
# Iteration: 1545, train loss: -6.115566792197911,
#                      test loss: -6.121701134937095
# Best model so far!
# Iteration: 1546, train loss: -6.11558522869969,
#                      test loss: -6.121717739857029
# Best model so far!
# Iteration: 1547, train loss: -6.115603641412536,
#                      test loss: -6.1217343233097115
# Best model so far!
# Iteration: 1548, train loss: -6.115622030367151,
#                      test loss: -6.121750885336744
# Best model so far!
# Iteration: 1549, train loss: -6.115640395547981,
#                      test loss: -6.121767425979623
# Best model so far!
# Iteration: 1550, train loss: -6.11565873709333,
#                      test loss: -6.121783945279737
# Best model so far!
# Iteration: 1551, train loss: -6.115677054972057,
#                      test loss: -6.121800443278367
# Best model so far!
# Iteration: 1552, train loss: -6.11569534924527,
#                      test loss: -6.12181692001669
# Best model so far!
# Iteration: 1553, train loss: -6.115713619927864,
#                      test loss: -6.1218333755357754
# Best model so far!
# Iteration: 1554, train loss: -6.115731867126751,
#                      test loss: -6.121849809876587
# Best model so far!
# Iteration: 1555, train loss: -6.11575009077991,
#                      test loss: -6.121866223079982
# Best model so far!
# Iteration: 1556, train loss: -6.115768291009351,
#                      test loss: -6.121882615186714
# Best model so far!
# Iteration: 1557, train loss: -6.115786467875517,
#                      test loss: -6.121898986237434
# Best model so far!
# Iteration: 1558, train loss: -6.1158046214846085,
#                      test loss: -6.121915336272683
# Best model so far!
# Iteration: 1559, train loss: -6.115822751774328,
#                      test loss: -6.1219316653329034
# Best model so far!
# Iteration: 1560, train loss: -6.115840858682536,
#                      test loss: -6.121947973458431
# Best model so far!
# Iteration: 1561, train loss: -6.1158589425596395,
#                      test loss: -6.121964260689499
# Best model so far!
# Iteration: 1562, train loss: -6.115877003220915,
#                      test loss: -6.121980527066238
# Best model so far!
# Iteration: 1563, train loss: -6.115895040787194,
#                      test loss: -6.121996772628676
# Best model so far!
# Iteration: 1564, train loss: -6.115913055348508,
#                      test loss: -6.1220129974167365
# Best model so far!
# Iteration: 1565, train loss: -6.115931046842315,
#                      test loss: -6.122029201470244
# Best model so far!
# Iteration: 1566, train loss: -6.115949015388929,
#                      test loss: -6.12204538482892
# Best model so far!
# Iteration: 1567, train loss: -6.115966961062712,
#                      test loss: -6.1220615475323825
# Best model so far!
# Iteration: 1568, train loss: -6.115984883755374,
#                      test loss: -6.122077689620153
# Best model so far!
# Iteration: 1569, train loss: -6.1160027837235935,
#                      test loss: -6.1220938111316485
# Best model so far!
# Iteration: 1570, train loss: -6.11602066079819,
#                      test loss: -6.122109912106186
# Best model so far!
# Iteration: 1571, train loss: -6.116038515083587,
#                      test loss: -6.122125992582984
# Best model so far!
# Iteration: 1572, train loss: -6.116056346638441,
#                      test loss: -6.12214205260116
# Best model so far!
# Iteration: 1573, train loss: -6.116074155566732,
#                      test loss: -6.122158092199733
# Best model so far!
# Iteration: 1574, train loss: -6.116091941835848,
#                      test loss: -6.122174111417621
# Best model so far!
# Iteration: 1575, train loss: -6.11610970556464,
#                      test loss: -6.122190110293646
# Best model so far!
# Iteration: 1576, train loss: -6.1161274467657565,
#                      test loss: -6.122206088866528
# Best model so far!
# Iteration: 1577, train loss: -6.116145165391342,
#                      test loss: -6.122222047174891
# Best model so far!
# Iteration: 1578, train loss: -6.116162861620297,
#                      test loss: -6.122237985257263
# Best model so far!
# Iteration: 1579, train loss: -6.11618053534418,
#                      test loss: -6.122253903152068
# Best model so far!
# Iteration: 1580, train loss: -6.1161981866359,
#                      test loss: -6.122269800897641
# Best model so far!
# Iteration: 1581, train loss: -6.116215815673748,
#                      test loss: -6.122285678532212
# Best model so far!
# Iteration: 1582, train loss: -6.116233422499922,
#                      test loss: -6.1223015360939215
# Best model so far!
# Iteration: 1583, train loss: -6.1162510069757845,
#                      test loss: -6.122317373620809
# Best model so far!
# Iteration: 1584, train loss: -6.11626856929418,
#                      test loss: -6.122333191150818
# Best model so far!
# Iteration: 1585, train loss: -6.116286109466963,
#                      test loss: -6.122348988721799
# Best model so far!
# Iteration: 1586, train loss: -6.116303627596156,
#                      test loss: -6.122364766371506
# Best model so far!
# Iteration: 1587, train loss: -6.116321123513101,
#                      test loss: -6.122380524137595
# Best model so far!
# Iteration: 1588, train loss: -6.116338597424915,
#                      test loss: -6.122396262057633
# Best model so far!
# Iteration: 1589, train loss: -6.116356049448163,
#                      test loss: -6.122411980169085
# Best model so far!
# Iteration: 1590, train loss: -6.116373479399221,
#                      test loss: -6.122427678509329
# Best model so far!
# Iteration: 1591, train loss: -6.116390887439593,
#                      test loss: -6.122443357115643
# Best model so far!
# Iteration: 1592, train loss: -6.1164082737153995,
#                      test loss: -6.122459016025216
# Best model so far!
# Iteration: 1593, train loss: -6.116425638058096,
#                      test loss: -6.122474655275141
# Best model so far!
# Iteration: 1594, train loss: -6.116442980658534,
#                      test loss: -6.122490274902419
# Best model so far!
# Iteration: 1595, train loss: -6.116460301512765,
#                      test loss: -6.122505874943958
# Best model so far!
# Iteration: 1596, train loss: -6.116477600646726,
#                      test loss: -6.122521455436572
# Best model so far!
# Iteration: 1597, train loss: -6.116494878205724,
#                      test loss: -6.122537016416985
# Best model so far!
# Iteration: 1598, train loss: -6.116512134110902,
#                      test loss: -6.122552557921828
# Best model so far!
# Iteration: 1599, train loss: -6.116529368343247,
#                      test loss: -6.12256807998764
# Best model so far!
# Iteration: 1600, train loss: -6.116546581062605,
#                      test loss: -6.12258358265087
# Best model so far!
# Iteration: 1601, train loss: -6.116563772219934,
#                      test loss: -6.122599065947875
# Best model so far!
# Iteration: 1602, train loss: -6.116580942034205,
#                      test loss: -6.122614529914921
# Best model so far!
# Iteration: 1603, train loss: -6.116598090411501,
#                      test loss: -6.122629974588185
# Best model so far!
# Iteration: 1604, train loss: -6.116615217451373,
#                      test loss: -6.1226454000037505
# Best model so far!
# Iteration: 1605, train loss: -6.1166323231491395,
#                      test loss: -6.122660806197615
# Best model so far!
# Iteration: 1606, train loss: -6.1166494074704385,
#                      test loss: -6.122676193205684
# Best model so far!
# Iteration: 1607, train loss: -6.116666470588704,
#                      test loss: -6.122691561063774
# Best model so far!
# Iteration: 1608, train loss: -6.116683512454533,
#                      test loss: -6.122706909807612
# Best model so far!
# Iteration: 1609, train loss: -6.116700533137184,
#                      test loss: -6.122722239472838
# Best model so far!
# Iteration: 1610, train loss: -6.116717532587278,
#                      test loss: -6.122737550095001
# Best model so far!
# Iteration: 1611, train loss: -6.1167345109035525,
#                      test loss: -6.1227528417095645
# Best model so far!
# Iteration: 1612, train loss: -6.11675146825845,
#                      test loss: -6.122768114351901
# Best model so far!
# Iteration: 1613, train loss: -6.1167684046318325,
#                      test loss: -6.122783368057297
# Best model so far!
# Iteration: 1614, train loss: -6.116785319944523,
#                      test loss: -6.122798602860952
# Best model so far!
# Iteration: 1615, train loss: -6.116802214398034,
#                      test loss: -6.122813818797977
# Best model so far!
# Iteration: 1616, train loss: -6.116819087883554,
#                      test loss: -6.122829015903396
# Best model so far!
# Iteration: 1617, train loss: -6.116835940513707,
#                      test loss: -6.122844194212148
# Best model so far!
# Iteration: 1618, train loss: -6.116852772179807,
#                      test loss: -6.122859353759085
# Best model so far!
# Iteration: 1619, train loss: -6.116869583097416,
#                      test loss: -6.122874494578972
# Best model so far!
# Iteration: 1620, train loss: -6.116886373246088,
#                      test loss: -6.122889616706489
# Best model so far!
# Iteration: 1621, train loss: -6.116903142781927,
#                      test loss: -6.12290472017623
# Best model so far!
# Iteration: 1622, train loss: -6.116919891640163,
#                      test loss: -6.122919805022703
# Best model so far!
# Iteration: 1623, train loss: -6.116936619844327,
#                      test loss: -6.122934871280333
# Best model so far!
# Iteration: 1624, train loss: -6.116953327417892,
#                      test loss: -6.122949918983458
# Best model so far!
# Iteration: 1625, train loss: -6.116970014472305,
#                      test loss: -6.1229649481663335
# Best model so far!
# Iteration: 1626, train loss: -6.116986680928123,
#                      test loss: -6.122979958863129
# Best model so far!
# Iteration: 1627, train loss: -6.117003326940556,
#                      test loss: -6.122994951107931
# Best model so far!
# Iteration: 1628, train loss: -6.117019952517987,
#                      test loss: -6.123009924934742
# Best model so far!
# Iteration: 1629, train loss: -6.1170365576687775,
#                      test loss: -6.123024880377481
# Best model so far!
# Iteration: 1630, train loss: -6.1170531425182855,
#                      test loss: -6.123039817469983
# Best model so far!
# Iteration: 1631, train loss: -6.117069706972289,
#                      test loss: -6.123054736246002
# Best model so far!
# Iteration: 1632, train loss: -6.11708625106828,
#                      test loss: -6.123069636739206
# Best model so far!
# Iteration: 1633, train loss: -6.11710277494586,
#                      test loss: -6.123084518983185
# Best model so far!
# Iteration: 1634, train loss: -6.117119278554603,
#                      test loss: -6.123099383011442
# Best model so far!
# Iteration: 1635, train loss: -6.117135761990027,
#                      test loss: -6.123114228857402
# Best model so far!
# Iteration: 1636, train loss: -6.117152225332845,
#                      test loss: -6.123129056554406
# Best model so far!
# Iteration: 1637, train loss: -6.117168668561622,
#                      test loss: -6.123143866135714
# Best model so far!
# Iteration: 1638, train loss: -6.117185091713195,
#                      test loss: -6.123158657634506
# Best model so far!
# Iteration: 1639, train loss: -6.117201494737037,
#                      test loss: -6.123173431083878
# Best model so far!
# Iteration: 1640, train loss: -6.117217877815341,
#                      test loss: -6.123188186516849
# Best model so far!
# Iteration: 1641, train loss: -6.117234240882871,
#                      test loss: -6.123202923966355
# Best model so far!
# Iteration: 1642, train loss: -6.1172505840923455,
#                      test loss: -6.123217643465252
# Best model so far!
# Iteration: 1643, train loss: -6.117266907363935,
#                      test loss: -6.1232323450463175
# Best model so far!
# Iteration: 1644, train loss: -6.11728321083554,
#                      test loss: -6.123247028742249
# Best model so far!
# Iteration: 1645, train loss: -6.117299494412827,
#                      test loss: -6.123261694585661
# Best model so far!
# Iteration: 1646, train loss: -6.117315758233449,
#                      test loss: -6.123276342609094
# Best model so far!
# Iteration: 1647, train loss: -6.1173320022754885,
#                      test loss: -6.123290972845005
# Best model so far!
# Iteration: 1648, train loss: -6.117348226705155,
#                      test loss: -6.1233055853257765
# Best model so far!
# Iteration: 1649, train loss: -6.117364431428003,
#                      test loss: -6.123320180083709
# Best model so far!
# Iteration: 1650, train loss: -6.1173806165376625,
#                      test loss: -6.123334757151026
# Best model so far!
# Iteration: 1651, train loss: -6.1173967819975665,
#                      test loss: -6.123349316559872
# Best model so far!
# Iteration: 1652, train loss: -6.117412927915561,
#                      test loss: -6.123363858342315
# Best model so far!
# Iteration: 1653, train loss: -6.117429054226147,
#                      test loss: -6.123378382530345
# Best model so far!
# Iteration: 1654, train loss: -6.117445161065792,
#                      test loss: -6.123392889155874
# Best model so far!
# Iteration: 1655, train loss: -6.117461248455384,
#                      test loss: -6.1234073782507386
# Best model so far!
# Iteration: 1656, train loss: -6.117477316444555,
#                      test loss: -6.123421849846696
# Best model so far!
# Iteration: 1657, train loss: -6.117493364996489,
#                      test loss: -6.123436303975428
# Best model so far!
# Iteration: 1658, train loss: -6.1175093941607335,
#                      test loss: -6.123450740668541
# Best model so far!
# Iteration: 1659, train loss: -6.117525403957978,
#                      test loss: -6.123465159957562
# Best model so far!
# Iteration: 1660, train loss: -6.117541394538122,
#                      test loss: -6.123479561873947
# Best model so far!
# Iteration: 1661, train loss: -6.117557365849753,
#                      test loss: -6.123493946449072
# Best model so far!
# Iteration: 1662, train loss: -6.117573317999376,
#                      test loss: -6.123508313714239
# Best model so far!
# Iteration: 1663, train loss: -6.1175892508925305,
#                      test loss: -6.123522663700673
# Best model so far!
# Iteration: 1664, train loss: -6.117605164735869,
#                      test loss: -6.123536996439529
# Best model so far!
# Iteration: 1665, train loss: -6.117621059320285,
#                      test loss: -6.123551311961881
# Best model so far!
# Iteration: 1666, train loss: -6.117636934923744,
#                      test loss: -6.123565610298733
# Best model so far!
# Iteration: 1667, train loss: -6.117652791423079,
#                      test loss: -6.12357989148101
# Best model so far!
# Iteration: 1668, train loss: -6.117668628938412,
#                      test loss: -6.1235941555395685
# Best model so far!
# Iteration: 1669, train loss: -6.117684447418155,
#                      test loss: -6.1236084025051865
# Best model so far!
# Iteration: 1670, train loss: -6.117700247010718,
#                      test loss: -6.12362263240857
# Best model so far!
# Iteration: 1671, train loss: -6.1177160277357405,
#                      test loss: -6.123636845280352
# Best model so far!
# Iteration: 1672, train loss: -6.117731789470223,
#                      test loss: -6.123651041151091
# Best model so far!
# Iteration: 1673, train loss: -6.117747532376475,
#                      test loss: -6.123665220051273
# Best model so far!
# Iteration: 1674, train loss: -6.117763256516726,
#                      test loss: -6.1236793820113125
# Best model so far!
# Iteration: 1675, train loss: -6.117778961824948,
#                      test loss: -6.123693527061548
# Best model so far!
# Iteration: 1676, train loss: -6.117794648477105,
#                      test loss: -6.1237076552322485
# Best model so far!
# Iteration: 1677, train loss: -6.117810316392835,
#                      test loss: -6.123721766553611
# Best model so far!
# Iteration: 1678, train loss: -6.117825965705095,
#                      test loss: -6.123735861055757
# Best model so far!
# Iteration: 1679, train loss: -6.117841596333526,
#                      test loss: -6.123749938768741
# Best model so far!
# Iteration: 1680, train loss: -6.117857208297299,
#                      test loss: -6.123763999722543
# Best model so far!
# Iteration: 1681, train loss: -6.117872801729008,
#                      test loss: -6.123778043947072
# Best model so far!
# Iteration: 1682, train loss: -6.117888376647529,
#                      test loss: -6.123792071472167
# Best model so far!
# Iteration: 1683, train loss: -6.117903933043365,
#                      test loss: -6.123806082327594
# Best model so far!
# Iteration: 1684, train loss: -6.117919471034462,
#                      test loss: -6.12382007654305
# Best model so far!
# Iteration: 1685, train loss: -6.117934990512091,
#                      test loss: -6.123834054148162
# Best model so far!
# Iteration: 1686, train loss: -6.117950491622325,
#                      test loss: -6.123848015172484
# Best model so far!
# Iteration: 1687, train loss: -6.117965974341294,
#                      test loss: -6.123861959645503
# Best model so far!
# Iteration: 1688, train loss: -6.117981438631064,
#                      test loss: -6.123875887596635
# Best model so far!
# Iteration: 1689, train loss: -6.1179968846514114,
#                      test loss: -6.123889799055226
# Best model so far!
# Iteration: 1690, train loss: -6.118012312477091,
#                      test loss: -6.123903694050552
# Best model so far!
# Iteration: 1691, train loss: -6.118027722027587,
#                      test loss: -6.123917572611821
# Best model so far!
# Iteration: 1692, train loss: -6.11804311330712,
#                      test loss: -6.123931434768171
# Best model so far!
# Iteration: 1693, train loss: -6.118058486404398,
#                      test loss: -6.123945280548671
# Best model so far!
# Iteration: 1694, train loss: -6.11807384135162,
#                      test loss: -6.123959109982324
# Best model so far!
# Iteration: 1695, train loss: -6.11808917818091,
#                      test loss: -6.12397292309806
# Best model so far!
# Iteration: 1696, train loss: -6.118104496952432,
#                      test loss: -6.123986719924746
# Best model so far!
# Iteration: 1697, train loss: -6.118119797571664,
#                      test loss: -6.124000500491175
# Best model so far!
# Iteration: 1698, train loss: -6.118135080211088,
#                      test loss: -6.124014264826078
# Best model so far!
# Iteration: 1699, train loss: -6.1181503448603545,
#                      test loss: -6.124028012958115
# Best model so far!
# Iteration: 1700, train loss: -6.118165591565234,
#                      test loss: -6.124041744915878
# Best model so far!
# Iteration: 1701, train loss: -6.118180820329344,
#                      test loss: -6.124055460727894
# Best model so far!
# Iteration: 1702, train loss: -6.118196031226329,
#                      test loss: -6.124069160422623
# Best model so far!
# Iteration: 1703, train loss: -6.118211224175666,
#                      test loss: -6.1240828440284565
# Best model so far!
# Iteration: 1704, train loss: -6.118226399320886,
#                      test loss: -6.124096511573719
# Best model so far!
# Iteration: 1705, train loss: -6.118241556721284,
#                      test loss: -6.12411016308667
# Best model so far!
# Iteration: 1706, train loss: -6.118256696338186,
#                      test loss: -6.1241237985955035
# Best model so far!
# Iteration: 1707, train loss: -6.118271818202847,
#                      test loss: -6.124137418128345
# Best model so far!
# Iteration: 1708, train loss: -6.118286922388324,
#                      test loss: -6.1241510217132555
# Best model so far!
# Iteration: 1709, train loss: -6.1183020089117015,
#                      test loss: -6.124164609378231
# Best model so far!
# Iteration: 1710, train loss: -6.118317077664539,
#                      test loss: -6.1241781811512
# Best model so far!
# Iteration: 1711, train loss: -6.118332128900946,
#                      test loss: -6.124191737060029
# Best model so far!
# Iteration: 1712, train loss: -6.1183471625680586,
#                      test loss: -6.124205277132514
# Best model so far!
# Iteration: 1713, train loss: -6.118362178710565,
#                      test loss: -6.124218801396393
# Best model so far!
# Iteration: 1714, train loss: -6.1183771773174085,
#                      test loss: -6.124232309879333
# Best model so far!
# Iteration: 1715, train loss: -6.118392158349753,
#                      test loss: -6.12424580260894
# Best model so far!
# Iteration: 1716, train loss: -6.118407122005051,
#                      test loss: -6.1242592796127555
# Best model so far!
# Iteration: 1717, train loss: -6.118422068160919,
#                      test loss: -6.124272740918255
# Best model so far!
# Iteration: 1718, train loss: -6.118436996931182,
#                      test loss: -6.124286186552853
# Best model so far!
# Iteration: 1719, train loss: -6.1184519082907025,
#                      test loss: -6.124299616543896
# Best model so far!
# Iteration: 1720, train loss: -6.118466802422326,
#                      test loss: -6.12431303091867
# Best model so far!
# Iteration: 1721, train loss: -6.1184816791898395,
#                      test loss: -6.124326429704398
# Best model so far!
# Iteration: 1722, train loss: -6.118496538665033,
#                      test loss: -6.124339812928238
# Best model so far!
# Iteration: 1723, train loss: -6.118511380988713,
#                      test loss: -6.124353180617284
# Best model so far!
# Iteration: 1724, train loss: -6.118526205983285,
#                      test loss: -6.124366532798572
# Best model so far!
# Iteration: 1725, train loss: -6.118541013803279,
#                      test loss: -6.1243798694990685
# Best model so far!
# Iteration: 1726, train loss: -6.118555804533799,
#                      test loss: -6.124393190745683
# Best model so far!
# Iteration: 1727, train loss: -6.118570578121702,
#                      test loss: -6.1244064965652605
# Best model so far!
# Iteration: 1728, train loss: -6.118585334555354,
#                      test loss: -6.124419786984584
# Best model so far!
# Iteration: 1729, train loss: -6.118600073933468,
#                      test loss: -6.124433062030374
# Best model so far!
# Iteration: 1730, train loss: -6.118614796244276,
#                      test loss: -6.124446321729291
# Best model so far!
# Iteration: 1731, train loss: -6.118629501668864,
#                      test loss: -6.124459566107931
# Best model so far!
# Iteration: 1732, train loss: -6.118644190071297,
#                      test loss: -6.1244727951928315
# Best model so far!
# Iteration: 1733, train loss: -6.118658861522313,
#                      test loss: -6.124486009010468
# Best model so far!
# Iteration: 1734, train loss: -6.11867351605124,
#                      test loss: -6.124499207587253
# Best model so far!
# Iteration: 1735, train loss: -6.11868815361863,
#                      test loss: -6.1245123909495405
# Best model so far!
# Iteration: 1736, train loss: -6.118702774294995,
#                      test loss: -6.124525559123622
# Best model so far!
# ...
# Best model so far!
# Iteration: 2867, train loss: -6.128709767920033,
#                      test loss: -6.133538363615644
# Best model so far!
# Iteration: 2868, train loss: -6.128715123584874,
#                      test loss: -6.133543187178246
# Best model so far!
# Iteration: 2869, train loss: -6.128720475524553,
#                      test loss: -6.133548007378307
# Best model so far!
# Iteration: 2870, train loss: -6.1287258237263496,
#                      test loss: -6.133552824219345
# Best model so far!
# Iteration: 2871, train loss: -6.128731168227388,
#                      test loss: -6.133557637704868
# Best model so far!
# Iteration: 2872, train loss: -6.128736508965122,
#                      test loss: -6.133562447838382
# Best model so far!
# Iteration: 2873, train loss: -6.128741845951779,
#                      test loss: -6.133567254623386
# Best model so far!
# Iteration: 2874, train loss: -6.128747179232753,
#                      test loss: -6.133572058063376
# Best model so far!
# Iteration: 2875, train loss: -6.128752508811912,
#                      test loss: -6.1335768581618435
# Best model so far!
# Iteration: 2876, train loss: -6.128757834734566,
#                      test loss: -6.133581654922272
# Best model so far!
# Iteration: 2877, train loss: -6.128763156929945,
#                      test loss: -6.133586448348145
# Best model so far!
# Iteration: 2878, train loss: -6.12876847549306,
#                      test loss: -6.133591238442936
# Best model so far!
# Iteration: 2879, train loss: -6.128773790295195,
#                      test loss: -6.133596025210116
# Best model so far!
# Iteration: 2880, train loss: -6.128779101356825,
#                      test loss: -6.133600808653153
# Best model so far!
# Iteration: 2881, train loss: -6.128784408748049,
#                      test loss: -6.133605588775507
# Best model so far!
# Iteration: 2882, train loss: -6.128789712464415,
#                      test loss: -6.133610365580635
# Best model so far!
# Iteration: 2883, train loss: -6.128795012534557,
#                      test loss: -6.13361513907199
# Best model so far!
# Iteration: 2884, train loss: -6.128800308854796,
#                      test loss: -6.133619909253018
# Best model so far!
# Iteration: 2885, train loss: -6.128805601594315,
#                      test loss: -6.133624676127161
# Best model so far!
# Iteration: 2886, train loss: -6.128810890690744,
#                      test loss: -6.133629439697857
# Best model so far!
# Iteration: 2887, train loss: -6.128816176065288,
#                      test loss: -6.133634199968538
# Best model so far!
# Iteration: 2888, train loss: -6.128821457763089,
#                      test loss: -6.133638956942634
# Best model so far!
# Iteration: 2889, train loss: -6.128826735812723,
#                      test loss: -6.133643710623566
# Best model so far!
# Iteration: 2890, train loss: -6.128832010176729,
#                      test loss: -6.133648461014754
# Best model so far!
# Iteration: 2891, train loss: -6.128837280982634,
#                      test loss: -6.133653208119611
# Best model so far!
# Iteration: 2892, train loss: -6.1288425481022255,
#                      test loss: -6.133657951941546
# Best model so far!
# Iteration: 2893, train loss: -6.128847811564048,
#                      test loss: -6.133662692483964
# Best model so far!
# Iteration: 2894, train loss: -6.128853071404849,
#                      test loss: -6.133667429750264
# Best model so far!
# Iteration: 2895, train loss: -6.128858327653085,
#                      test loss: -6.133672163743841
# Best model so far!
# Iteration: 2896, train loss: -6.128863580246618,
#                      test loss: -6.133676894468086
# Best model so far!
# Iteration: 2897, train loss: -6.128868829205691,
#                      test loss: -6.133681621926383
# Best model so far!
# Iteration: 2898, train loss: -6.128874074542295,
#                      test loss: -6.133686346122114
# Best model so far!
# Iteration: 2899, train loss: -6.1288793162684,
#                      test loss: -6.133691067058656
# Best model so far!
# Iteration: 2900, train loss: -6.128884554379523,
#                      test loss: -6.13369578473938
# Best model so far!
# Iteration: 2901, train loss: -6.128889788862963,
#                      test loss: -6.133700499167651
# Best model so far!
# Iteration: 2902, train loss: -6.128895019730688,
#                      test loss: -6.133705210346834
# Best model so far!
# Iteration: 2903, train loss: -6.128900246994645,
#                      test loss: -6.133709918280285
# Best model so far!
# Iteration: 2904, train loss: -6.128905470691398,
#                      test loss: -6.133714622971358
# Best model so far!
# Iteration: 2905, train loss: -6.1289106907425595,
#                      test loss: -6.133719324423401
# Best model so far!
# Iteration: 2906, train loss: -6.128915907225731,
#                      test loss: -6.133724022639758
# Best model so far!
# Iteration: 2907, train loss: -6.128921120128193,
#                      test loss: -6.133728717623767
# Best model so far!
# Iteration: 2908, train loss: -6.128926329396247,
#                      test loss: -6.133733409378765
# Best model so far!
# Iteration: 2909, train loss: -6.128931535082819,
#                      test loss: -6.13373809790808
# Best model so far!
# Iteration: 2910, train loss: -6.12893673722437,
#                      test loss: -6.1337427832150375
# Best model so far!
# Iteration: 2911, train loss: -6.128941935767224,
#                      test loss: -6.133747465302959
# Best model so far!
# Iteration: 2912, train loss: -6.128947130756026,
#                      test loss: -6.133752144175162
# Best model so far!
# Iteration: 2913, train loss: -6.1289523222189874,
#                      test loss: -6.133756819834956
# Best model so far!
# Iteration: 2914, train loss: -6.128957510037014,
#                      test loss: -6.13376149228565
# Best model so far!
# Iteration: 2915, train loss: -6.128962694320182,
#                      test loss: -6.133766161530545
# Best model so far!
# Iteration: 2916, train loss: -6.12896787507213,
#                      test loss: -6.133770827572941
# Best model so far!
# Iteration: 2917, train loss: -6.128973052239274,
#                      test loss: -6.13377549041613
# Best model so far!
# Iteration: 2918, train loss: -6.1289782258661525,
#                      test loss: -6.133780150063402
# Best model so far!
# Iteration: 2919, train loss: -6.128983395915567,
#                      test loss: -6.133784806518042
# Best model so far!
# Iteration: 2920, train loss: -6.1289885624891705,
#                      test loss: -6.133789459783329
# Best model so far!
# Iteration: 2921, train loss: -6.128993725476264,
#                      test loss: -6.133794109862539
# Best model so far!
# Iteration: 2922, train loss: -6.128998884994761,
#                      test loss: -6.133798756758943
# Best model so far!
# Iteration: 2923, train loss: -6.129004040974811,
#                      test loss: -6.133803400475808
# Best model so far!
# Iteration: 2924, train loss: -6.129009193509738,
#                      test loss: -6.133808041016397
# Best model so far!
# Iteration: 2925, train loss: -6.129014342440054,
#                      test loss: -6.133812678383966
# Best model so far!
# Iteration: 2926, train loss: -6.1290194878101945,
#                      test loss: -6.133817312581769
# Best model so far!
# Iteration: 2927, train loss: -6.12902462969712,
#                      test loss: -6.1338219436130546
# Best model so far!
# Iteration: 2928, train loss: -6.129029768071827,
#                      test loss: -6.133826571481069
# Best model so far!
# Iteration: 2929, train loss: -6.129034902872794,
#                      test loss: -6.133831196189049
# Best model so far!
# Iteration: 2930, train loss: -6.129040034266424,
#                      test loss: -6.133835817740232
# Best model so far!
# Iteration: 2931, train loss: -6.129045162158591,
#                      test loss: -6.13384043613785
# Best model so far!
# Iteration: 2932, train loss: -6.129050286479694,
#                      test loss: -6.133845051385127
# Best model so far!
# Iteration: 2933, train loss: -6.12905540733093,
#                      test loss: -6.133849663485288
# Best model so far!
# Iteration: 2934, train loss: -6.129060524675218,
#                      test loss: -6.133854272441549
# Best model so far!
# Iteration: 2935, train loss: -6.129065638581129,
#                      test loss: -6.133858878257124
# Best model so far!
# Iteration: 2936, train loss: -6.129070748970971,
#                      test loss: -6.133863480935223
# Best model so far!
# Iteration: 2937, train loss: -6.1290758558970415,
#                      test loss: -6.133868080479051
# Best model so far!
# Iteration: 2938, train loss: -6.129080959338532,
#                      test loss: -6.133872676891807
# Best model so far!
# Iteration: 2939, train loss: -6.129086059290889,
#                      test loss: -6.133877270176687
# Best model so far!
# Iteration: 2940, train loss: -6.129091155765781,
#                      test loss: -6.133881860336884
# Best model so far!
# Iteration: 2941, train loss: -6.129096248791075,
#                      test loss: -6.133886447375585
# Best model so far!
# Iteration: 2942, train loss: -6.1291013383702895,
#                      test loss: -6.133891031295973
# Best model so far!
# Iteration: 2943, train loss: -6.129106424490735,
#                      test loss: -6.133895612101226
# Best model so far!
# Iteration: 2944, train loss: -6.129111507147837,
#                      test loss: -6.133900189794519
# Best model so far!
# Iteration: 2945, train loss: -6.129116586393697,
#                      test loss: -6.133904764379022
# Best model so far!
# Iteration: 2946, train loss: -6.129121662118489,
#                      test loss: -6.133909335857901
# Best model so far!
# Iteration: 2947, train loss: -6.129126734422879,
#                      test loss: -6.133913904234317
# Best model so far!
# Iteration: 2948, train loss: -6.129131803286087,
#                      test loss: -6.1339184695114275
# Best model so far!
# Iteration: 2949, train loss: -6.129136868727779,
#                      test loss: -6.133923031692385
# Best model so far!
# Iteration: 2950, train loss: -6.129141930727194,
#                      test loss: -6.133927590780339
# Best model so far!
# Iteration: 2951, train loss: -6.129146989263589,
#                      test loss: -6.133932146778433
# Best model so far!
# Iteration: 2952, train loss: -6.129152044421251,
#                      test loss: -6.133936699689808
# Best model so far!
# Iteration: 2953, train loss: -6.129157096130948,
#                      test loss: -6.133941249517599
# Best model so far!
# Iteration: 2954, train loss: -6.129162144404253,
#                      test loss: -6.133945796264937
# Best model so far!
# Iteration: 2955, train loss: -6.12916718926079,
#                      test loss: -6.133950339934951
# Best model so far!
# Iteration: 2956, train loss: -6.129172230736291,
#                      test loss: -6.133954880530763
# Best model so far!
# Iteration: 2957, train loss: -6.129177268834185,
#                      test loss: -6.133959418055492
# Best model so far!
# Iteration: 2958, train loss: -6.129182303477295,
#                      test loss: -6.1339639525122545
# Best model so far!
# Iteration: 2959, train loss: -6.129187334693299,
#                      test loss: -6.133968483904158
# Best model so far!
# Iteration: 2960, train loss: -6.129192362582324,
#                      test loss: -6.133973012234311
# Best model so far!
# Iteration: 2961, train loss: -6.12919738701891,
#                      test loss: -6.133977537505814
# Best model so far!
# Iteration: 2962, train loss: -6.129202408062899,
#                      test loss: -6.133982059721767
# Best model so far!
# Iteration: 2963, train loss: -6.129207425717726,
#                      test loss: -6.133986578885261
# Best model so far!
# Iteration: 2964, train loss: -6.129212439962689,
#                      test loss: -6.133991094999387
# Best model so far!
# Iteration: 2965, train loss: -6.129217450857527,
#                      test loss: -6.133995608067231
# Best model so far!
# Iteration: 2966, train loss: -6.129222458381513,
#                      test loss: -6.1340001180918735
# Best model so far!
# Iteration: 2967, train loss: -6.129227462578232,
#                      test loss: -6.134004625076391
# Best model so far!
# Iteration: 2968, train loss: -6.129232463338588,
#                      test loss: -6.134009129023857
# Best model so far!
# Iteration: 2969, train loss: -6.129237460762416,
#                      test loss: -6.134013629937341
# Best model so far!
# Iteration: 2970, train loss: -6.129242454837029,
#                      test loss: -6.134018127819906
# Best model so far!
# Iteration: 2971, train loss: -6.129247445549762,
#                      test loss: -6.134022622674613
# Best model so far!
# Iteration: 2972, train loss: -6.129252432863896,
#                      test loss: -6.134027114504519
# Best model so far!
# Iteration: 2973, train loss: -6.129257416855037,
#                      test loss: -6.1340316033126765
# Best model so far!
# Iteration: 2974, train loss: -6.129262397454384,
#                      test loss: -6.134036089102133
# Best model so far!
# Iteration: 2975, train loss: -6.129267374753514,
#                      test loss: -6.134040571875933
# Best model so far!
# Iteration: 2976, train loss: -6.129272348699673,
#                      test loss: -6.134045051637115
# Best model so far!
# Iteration: 2977, train loss: -6.12927731930425,
#                      test loss: -6.134049528388718
# Best model so far!
# Iteration: 2978, train loss: -6.129282286522574,
#                      test loss: -6.13405400213377
# Best model so far!
# Iteration: 2979, train loss: -6.129287250414078,
#                      test loss: -6.134058472875302
# Best model so far!
# Iteration: 2980, train loss: -6.1292922110301165,
#                      test loss: -6.134062940616336
# Best model so far!
# Iteration: 2981, train loss: -6.129297168302003,
#                      test loss: -6.134067405359891
# Best model so far!
# Iteration: 2982, train loss: -6.1293021222251065,
#                      test loss: -6.134071867108984
# Best model so far!
# Iteration: 2983, train loss: -6.129307072770826,
#                      test loss: -6.134076325866627
# Best model so far!
# Iteration: 2984, train loss: -6.129312019998485,
#                      test loss: -6.134080781635826
# Best model so far!
# Iteration: 2985, train loss: -6.1293169639513545,
#                      test loss: -6.134085234419585
# Best model so far!
# Iteration: 2986, train loss: -6.1293219046247405,
#                      test loss: -6.134089684220903
# Best model so far!
# Iteration: 2987, train loss: -6.129326841926154,
#                      test loss: -6.134094131042776
# Best model so far!
# Iteration: 2988, train loss: -6.129331775994627,
#                      test loss: -6.1340985748881955
# Best model so far!
# Iteration: 2989, train loss: -6.129336706745663,
#                      test loss: -6.134103015760148
# Best model so far!
# Iteration: 2990, train loss: -6.129341634182589,
#                      test loss: -6.134107453661619
# Best model so far!
# Iteration: 2991, train loss: -6.129346558324674,
#                      test loss: -6.134111888595585
# Best model so far!
# Iteration: 2992, train loss: -6.129351479183188,
#                      test loss: -6.134116320565024
# Best model so far!
# Iteration: 2993, train loss: -6.129356396729559,
#                      test loss: -6.134120749572906
# Best model so far!
# Iteration: 2994, train loss: -6.129361311030812,
#                      test loss: -6.1341251756221995
# Best model so far!
# Iteration: 2995, train loss: -6.1293662220663165,
#                      test loss: -6.134129598715867
# Best model so far!
# Iteration: 2996, train loss: -6.129371129791594,
#                      test loss: -6.134134018856868
# Best model so far!
# Iteration: 2997, train loss: -6.12937603424178,
#                      test loss: -6.134138436048159
# Best model so far!
# Iteration: 2998, train loss: -6.129380935475819,
#                      test loss: -6.134142850292691
# Best model so far!
# Iteration: 2999, train loss: -6.12938583340153,
#                      test loss: -6.134147261593412
# Best model so far!
# Iteration: 3000, train loss: -6.129390728054009,
#                      test loss: -6.134151669953267
# Best model so far!

# %%
# Save the scaler
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %% [markdown]
# ## Environment Drift Detection

# %%
env1 = Continuous_MountainCarEnv() # Undrifted Production Environment
env2 = Continuous_MountainCarEnvWithWind(wind_direction="left",
                                         windpower=0.35) # Drifted Production Environment

# %%
class StatePredictor(ApproximateGP):
  def __init__(self, inducing_points):
    inducing_points = inducing_points
    variational_distribution = CholeskyVariationalDistribution(inducing_points.size(-2),
                                                               batch_shape=torch.Size([n_tasks]))

    variational_strategy = gpytorch.variational.IndependentMultitaskVariationalStrategy(
                                                   VariationalStrategy(self, inducing_points,
                                                       variational_distribution,
                                                       learn_inducing_locations=True),
                                                num_tasks=n_tasks
                                             )

    super(StatePredictor, self).__init__(variational_strategy)
    self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([n_tasks]))
    self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel(batch_shape=torch.Size([n_tasks]),
                                                                                ard_num_dims=X_train_env0_tensor.size(-1)),
                                                    batch_shape = torch.Size([n_tasks])
                                                  )

  def forward(self, x):
    mean_x = self.mean_module(x)
    covar_x = self.covar_module(x)
    return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# %%
# Load the scaler
import pickle

with open('scaler.pkl', 'rb') as f:
    scaler = pickle.load(f)


# Load the GP model
model_gp_env0 = torch.load("model_gp_env0.pth")

# %%
with torch.no_grad():

  env1_step = 3000
  env2_step = 3000

  total_step = env1_step + env2_step

  compute_mse_steps = 100
  #mse_compute_buffer = deque([], maxlen=compute_mse_steps)
  obs_true = deque([], maxlen=compute_mse_steps)
  obs_predicted = deque([], maxlen=compute_mse_steps)


  n_past_steps_to_store = 500
  replay_buffer = deque([], maxlen=n_past_steps_to_store)

  #mses = deque([], maxlen=n_past_steps_to_store)
  mses_production = []



  env_current = env1
  obs_t = env_current.reset() # Initialize the environment

  for t in range(1, total_step+1):

    if t%500 == 0:
     print(f"step {t}")

    action_t, _state = model.predict(obs_t, deterministic=True)
    obs_tplus1, r_tplus1, terminated, truncated, info = env_current.step(action_t)
    replay_buffer.append([obs_t, action_t, obs_tplus1, r_tplus1, t])

    x = np.concatenate([obs_t, action_t]).reshape(1,-1)
    x = scaler.transform(x)
    x = torch.from_numpy(x)
    x = x.to(device)

    y = obs_tplus1-obs_t

    y_predicted = model_gp_env0(x)



    mses_production.append(mse(y, y_predicted.mean.flatten().detach().cpu().numpy()))


    done = terminated or truncated

    obs_t = obs_tplus1

    if done:
      obs_t = env_current.reset()

    if t==env1_step: ## Environment Drift Happens
      env_current = env2
      obs_t = env_current.reset()
# Out:
# step 500
# step 1000
# step 1500
# step 2000
# step 2500
# step 3000
# step 3500
# step 4000
# step 4500
# step 5000
# step 5500
# step 6000

# %%
plt.plot(np.array(mses_production))
#plt.axvline(x=3000, label="Environment Drift", color='red')
plt.xlabel("step")
plt.ylabel("MSE")
#plt.legend()
plt.xticks(np.arange(0, 6001, 250), rotation=70)
plt.title("SAC MountainCar")
plt.show()

# %% [markdown]
# ### Environment Drift Detection with Prob CUSUM

# %%
class CusumMeanDetector():
  def __init__(self, mu_ref, sigma_ref, obs_ref, p_limit=0.01) -> None:
    self._mu_ref = mu_ref
    self._sigma_ref = sigma_ref
    self._p_limit = p_limit

    self._reset(obs_ref)

  def _reset(self, obs_ref) -> None:
    self.current_t = len(obs_ref)
    self.current_obs = obs_ref.copy()
    #self.mu_current = self._mu_ref
    #self.sigma_current = self._sigma_ref

  def _update_data(self, y:float) -> None:
    self.current_t += 1
    self.current_obs.append(y)

  def _get_pvalue(self, y, alternative="two-sided") -> float:
    assert alternative in {"two-sided", "greater", "less"}
    pcum = scipy.stats.norm.cdf(y, loc=0., scale=1.)
    if alternative == "two-sided":
      p = 2*(1-pcum)
    if alternative == "greater":
      p = 1-pcum
    if alternative == "less":
      p = pcum
    return p

  def _check_for_changepoint(self, alternative) -> Tuple[float, bool]:
    standardized_sum = np.sum(np.array(self.current_obs)-self._mu_ref)/(self._sigma_ref*self.current_t**0.5)
    p = self._get_pvalue(standardized_sum, alternative)
    return p, p < self._p_limit


  def predict_next(self, y, alternative="two-sided") -> Tuple[float, bool]:
    self._update_data(y)
    p, is_changepoint = self._check_for_changepoint(alternative)
    return p, is_changepoint

# %%
# Environment Drift Detection with CUSUM
env0_steps = 4000
window_size = 200
mses_reference = []
p_limit = 0.05
obs_t = env0.reset()
for t in range(env0_steps):
  action_t, _state = model.predict(obs_t, deterministic=True)
  obs_tplus1, r_tplus1, terminated, truncated, info = env0.step(action_t)
  #x = np.concatenate([obs_t, obs_tplus1-obs_t]).reshape(1,-1)
  #x = scaler.transform(x)
  #x = torch.from_numpy(x.astype("float32")).to(device)
  #action_t_pre = model_gp_env0(x)
  x = np.concatenate([obs_t,action_t]).reshape(1,-1)
  x = scaler.transform(x)
  x = torch.from_numpy(x)
  x = x.to(device)

  y = obs_tplus1-obs_t

  with torch.no_grad():
    y_predicted = model_gp_env0(x)



  mses_reference.append(mse(y, y_predicted.mean.flatten().detach().cpu().numpy()))

  done = terminated or truncated
  obs_t = obs_tplus1
  if done:
    obs_t = env0.reset()

#print(f"Reference mean: {np.mean(mses_reference)}, Reference std: {np.std(mses_reference)}")

mu_ref = np.mean(mses_reference)
sigma_ref = np.std(mses_reference, ddof=1)
mses_reference_window = np.random.choice(mses_reference, size=window_size, replace=False).tolist()

drift_detector = CusumMeanDetector(mu_ref=mu_ref,
                                   sigma_ref = sigma_ref,
                                   obs_ref=mses_reference_window,
                                   p_limit = p_limit)

false_alarms = 0
delay = 4000


for i,val in enumerate(mses_production):
  #drift_detector.add_data_point(val)
  p_value, drift_detected = drift_detector.predict_next(val, alternative="greater")
  if drift_detected:
    print(f"Drift Detected at: {i} with value: {val}")
    mses_reference_window = np.random.choice(mses_reference, size=window_size, replace=False).tolist()
    drift_detector._reset(mses_reference_window)
    if i < 3000:
      false_alarms+=1
    if i >= 3000:
      delay = i-3000
      break


print(f"False Alarms: {false_alarms}, Delay: {delay}")
# Out:
# False Alarms: 0, Delay: 4000

# %% [markdown]
# ### Page-Hinkley

# %%
ph = drift.PageHinkley(mode="up", delta=0.005)

env0_steps = 4000
#window_size = 200
mses_reference = []
p_limit = 0.05
obs_t = env0.reset()
for t in range(env0_steps):
  action_t, _state = model.predict(obs_t, deterministic=True)
  obs_tplus1, r_tplus1, terminated, truncated, info = env0.step(action_t)
  #x = np.concatenate([obs_t, obs_tplus1-obs_t]).reshape(1,-1)
  #x = scaler.transform(x)
  #x = torch.from_numpy(x.astype("float32")).to(device)
  #action_t_pre = model_gp_env0(x)
  x = np.concatenate([obs_t,action_t]).reshape(1,-1)
  x = scaler.transform(x)
  x = torch.from_numpy(x)
  x = x.to(device)

  y = obs_tplus1-obs_t

  with torch.no_grad():
    y_predicted = model_gp_env0(x)



  mses_reference.append(mse(y, y_predicted.mean.flatten().detach().cpu().numpy()))

  done = terminated or truncated
  obs_t = obs_tplus1
  if done:
    obs_t = env0.reset()

#print(f"Reference mean: {np.mean(mses_reference)}, Reference std: {np.std(mses_reference)}")

mu_ref = np.mean(mses_reference)
sigma_ref = np.std(mses_reference, ddof=1)

mses_production_norm = (mses_production-mu_ref)/sigma_ref

false_alarms = 0
delay = 4000

for i, val in enumerate(mses_production_norm):
  ph.update(val)
  if ph.drift_detected and val>0:
    print(f"Change detected at index {i}, input value: {val}")
    if i<3000:
      false_alarms+=1
    if i>=3000:
      delay = i-3000
      break

print(f"False Alarms: {false_alarms}, Delay: {delay}")
# Out:
# Change detected at index 3607, input value: 35.32854461669922
# False Alarms: 0, Delay: 607

# %% [markdown]
# ### ADWIN

# %%
adwin = drift.ADWIN()


env0_steps = 4000
mses_reference = []
p_limit = 0.05
obs_t = env0.reset()
for t in range(env0_steps):
  action_t, _state = model.predict(obs_t, deterministic=True)
  obs_tplus1, r_tplus1, terminated, truncated, info = env0.step(action_t)

  x = np.concatenate([obs_t,action_t]).reshape(1,-1)
  x = scaler.transform(x)
  x = torch.from_numpy(x)
  x = x.to(device)

  y = obs_tplus1-obs_t

  with torch.no_grad():
    y_predicted = model_gp_env0(x)

  mses_reference.append(mse(y, y_predicted.mean.flatten().detach().cpu().numpy()))

  done = terminated or truncated
  obs_t = obs_tplus1
  if done:
    obs_t = env0.reset()


mu_ref = np.mean(mses_reference)
sigma_ref = np.std(mses_reference, ddof=1)

mses_production_norm = (mses_production-mu_ref)/sigma_ref


false_alarms = 0
delay = 4000

for i, val in enumerate(mses_production_norm):
  adwin.update(val)
  if adwin.drift_detected and val>0:
    print(f"Change detected at index {i}, input value: {val}")
    if i<3000:
      false_alarms+=1
    if i>=3000:
      delay = i-3000
      break

print(f"False Alarms: {false_alarms}, Delay: {delay}")
# Out:
# False Alarms: 0, Delay: 4000

# %% [markdown]
# ### KSWIN

# %%
kswin = drift.KSWIN()


env0_steps = 4000
mses_reference = []
p_limit = 0.05
obs_t = env0.reset()
for t in range(env0_steps):
  action_t, _state = model.predict(obs_t, deterministic=True)
  obs_tplus1, r_tplus1, terminated, truncated, info = env0.step(action_t)

  x = np.concatenate([obs_t,action_t]).reshape(1,-1)
  x = scaler.transform(x)
  x = torch.from_numpy(x)
  x = x.to(device)

  y = obs_tplus1-obs_t

  with torch.no_grad():
    y_predicted = model_gp_env0(x)

  mses_reference.append(mse(y, y_predicted.mean.flatten().detach().cpu().numpy()))

  done = terminated or truncated
  obs_t = obs_tplus1
  if done:
    obs_t = env0.reset()


mu_ref = np.mean(mses_reference)
sigma_ref = np.std(mses_reference, ddof=1)

mses_production_norm = (mses_production-mu_ref)/sigma_ref


false_alarms = 0
delay = 4000

for i, val in enumerate(mses_production_norm):
  kswin.update(val)
  if kswin.drift_detected and val>0:
    print(f"Change detected at index {i}, input value: {val}")
    if i<3000:
      false_alarms+=1
    if i>=3000:
      delay = i-3000
      break

print(f"False Alarms: {false_alarms}, Delay: {delay}")
# Out:
# Change detected at index 514, input value: 0.02305196039378643
# Change detected at index 2775, input value: 0.06515844911336899
# Change detected at index 3209, input value: 0.0652991458773613
# False Alarms: 2, Delay: 209

# %%
# !pip install gpytorch
# !apt-get install swig3.0
# !ln -s /usr/bin/swig3.0 /usr/bin/swig
# !pip install gymnasium
# !pip install gymnasium[classic-control]
# !pip install stable-baselines3[extra]
# !pip install huggingface_hub
# !pip install huggingface-sb3
# !pip install river
# Out:
# Collecting gpytorch
#   Downloading gpytorch-1.12-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in /usr/local/lib/python3.10/dist-packages (from gpytorch) (1.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from gpytorch) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gpytorch) (1.13.1)
# Collecting linear-operator>=0.5.2 (from gpytorch)
#   Downloading linear_operator-0.5.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from linear-operator>=0.5.2->gpytorch) (2.3.1+cu121)
# Collecting jaxtyping>=0.2.9 (from linear-operator>=0.5.2->gpytorch)
#   Downloading jaxtyping-0.2.33-py3-none-any.whl.metadata (6.4 kB)
# Collecting typeguard~=2.13.3 (from linear-operator>=0.5.2->gpytorch)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->gpytorch) (1.26.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->gpytorch) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->gpytorch) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->linear-operator>=0.5.2->gpytorch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->linear-operator>=0.5.2->gpytorch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->linear-operator>=0.5.2->gpytorch) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->linear-operator>=0.5.2->gpytorch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->linear-operator>=0.5.2->gpytorch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->linear-operator>=0.5.2->gpytorch) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->linear-operator>=0.5.2->gpytorch) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11->linear-operator>=0.5.2->gpytorch)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->linear-operator>=0.5.2->gpytorch) (2.1.5)
# Downloading gpytorch-1.12-py3-none-any.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.1/274.1 kB 5.4 MB/s eta 0:00:00
# Downloading linear_operator-0.5.2-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.6/175.6 kB 10.4 MB/s eta 0:00:00
# Downloading jaxtyping-0.2.33-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 2.4 MB/s eta 0:00:00
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 9.9 MB/s eta 0:00:00
# Installing collected packages: typeguard, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jaxtyping, nvidia-cusolver-cu12, linear-operator, gpytorch
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.3.0
#     Uninstalling typeguard-4.3.0:
#       Successfully uninstalled typeguard-4.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# inflect 7.3.1 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed gpytorch-1.12 jaxtyping-0.2.33 linear-operator-0.5.2 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 typeguard-2.13.3
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   swig3.0-examples swig3.0-doc
# The following NEW packages will be installed:
#   swig3.0
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 1,109 kB of archives.
# After this operation, 5,555 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig3.0 amd64 3.0.12-2.2ubuntu1 [1,109 kB]
# Fetched 1,109 kB in 1s (800 kB/s)
# Selecting previously unselected package swig3.0.
# (Reading database ... 123588 files and directories currently installed.)
# Preparing to unpack .../swig3.0_3.0.12-2.2ubuntu1_amd64.deb ...
# Unpacking swig3.0 (3.0.12-2.2ubuntu1) ...
# Setting up swig3.0 (3.0.12-2.2ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting gymnasium
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 18.5 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1
# Requirement already satisfied: gymnasium[classic-control] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from gymnasium[classic-control]) (2.6.0)
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-2.3.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.3.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.1.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.6.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.15.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.66.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (13.7.1)
# Collecting shimmy~=1.3.0 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra])
#   Downloading Shimmy-1.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (9.4.0)
# Collecting autorom~=0.6.1 (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.31.0)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 8.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra])
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.64.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (71.0.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3[extra]) (12.5.82)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (2.16.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (6.4.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Downloading stable_baselines3-2.3.2-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 14.2 MB/s eta 0:00:00
# Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 44.7 MB/s eta 0:00:00
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446662 sha256=a153feae5697a2ae5d35a6b50233fa2bf88eef67b90f523414be5318b3df358b
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: ale-py, shimmy, AutoROM.accept-rom-license, autorom, stable-baselines3
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 shimmy-1.3.0 stable-baselines3-2.3.2
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.23.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.7.4)
# Collecting huggingface-sb3
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3) (0.23.5)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3) (6.0.1)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3) (1.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.6 in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3) (2.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3) (2024.7.4)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Installing collected packages: huggingface-sb3
# Successfully installed huggingface-sb3-3.0
# Collecting river
#   Downloading river-0.21.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from river) (1.26.4)
# Requirement already satisfied: pandas<3.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from river) (2.1.4)
# Requirement already satisfied: scipy<2.0.0,>=1.12.1 in /usr/local/lib/python3.10/dist-packages (from river) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=2.1->river) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=2.1->river) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=2.1->river) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=2.1->river) (1.16.0)
# Downloading river-0.21.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 38.9 MB/s eta 0:00:00
# Installing collected packages: river
# Successfully installed river-0.21.2

# %%
import numpy as np
import pandas as pd

import gymnasium as gym
from gymnasium.wrappers import TransformReward, TransformObservation

from sklearn.metrics import mean_squared_error as mse
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

import scipy
from scipy.stats import norm
from scipy.special import logsumexp

import torch
from torch.optim.lr_scheduler import ExponentialLR
from torch.utils.data import TensorDataset, DataLoader
import gpytorch
from gpytorch.models import ApproximateGP
from gpytorch.variational import CholeskyVariationalDistribution
from gpytorch.variational import VariationalStrategy

from huggingface_sb3 import load_from_hub
from stable_baselines3 import SAC
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import is_wrapped

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, PillowWriter
from matplotlib.colors import LogNorm

from collections import deque

from typing import Tuple

import scipy
from scipy.stats import multivariate_normal

from river import drift

# %% [markdown]
# ## Load Trained Policy from HuggingFace

# %%
checkpoint = load_from_hub(
    repo_id = "sb3/sac-Pendulum-v1",
    filename = "sac-Pendulum-v1.zip",
)

model = SAC.load(checkpoint)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# sac-Pendulum-v1.zip:   0%|          | 0.00/3.01M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/save_util.py:167: UserWarning: Could not deserialize object learning_rate. Consider using `custom_objects` argument to replace this object.
# Exception: 'bytes' object cannot be interpreted as an integer
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/save_util.py:167: UserWarning: Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: 'bytes' object cannot be interpreted as an integer
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(

# %% [markdown]
# ## Create Environment

# %%
env0 = gym.make("Pendulum-v1", g=10.0) # Training Environment
env1 = gym.make("Pendulum-v1", g=10.0) # Undrifted Production Environment
env2 = gym.make("Pendulum-v1", g=10.5) # Drifted Production Environment

# %% [markdown]
# ## Device

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %% [markdown]
# ## Train SVGP StatePredictor on Training Environment

# %%
observations = []
actions = []
rewards = []
dones = []
sources = []
targets = []

obs_t, _ = env0.reset()
observations.append(obs_t)

for i in range(20000):
  action_t, _state = model.predict(obs_t, deterministic=True)
  actions.append(action_t)
  obs_tplus1, r_tplus1, terminated, truncated, info = env0.step(action_t)

  done = terminated or truncated
  dones.append(done)

  observations.append(obs_tplus1)
  rewards.append(r_tplus1)
  #sources.append(obs_t)
  sources.append(np.concatenate([obs_t, action_t]))
  targets.append(obs_tplus1-obs_t)

  obs_t = obs_tplus1

  if done:
    obs_t, _ = env0.reset()

sources = np.array(sources)
targets = np.array(targets)

n_train = int(len(sources)*0.8)

# %%
X_train_env0, X_test_env0, y_train_env0, y_test_env0 = sources[:n_train], sources[n_train:], targets[:n_train],  targets[n_train:]
scaler = StandardScaler()
scaler.fit(X_train_env0)
X_train_env0_scaled = scaler.transform(X_train_env0)
X_test_env0_scaled = scaler.transform(X_test_env0)

# get the number of tasks (the prediction dimensions)
n_tasks = y_train_env0.shape[-1]

# Compute inducing points
n_inducing = 100
kmeans = KMeans(n_clusters=n_inducing).fit(X_train_env0_scaled)
inducing_points = kmeans.cluster_centers_
inducing_points = torch.from_numpy(inducing_points.astype(np.float32))
inducing_points = torch.concat([inducing_points]*n_tasks, dim=0)
inducing_points = inducing_points.reshape(n_tasks, n_inducing, -1)

X_train_env0_tensor = torch.from_numpy(X_train_env0_scaled).contiguous().to(device)
X_test_env0_tensor = torch.from_numpy(X_test_env0_scaled).contiguous().to(device)
y_train_env0_tensor = torch.from_numpy(y_train_env0).contiguous().to(device)
y_test_env0_tensor = torch.from_numpy(y_test_env0).contiguous().to(device)


train_dataset = TensorDataset(X_train_env0_tensor, y_train_env0_tensor)
train_loader = DataLoader(train_dataset, batch_size=800, shuffle=True)
test_dataset = TensorDataset(X_test_env0_tensor, y_test_env0_tensor)
test_loader = DataLoader(test_dataset, batch_size=800, shuffle=False)

class StatePredictor(ApproximateGP):
  def __init__(self, inducing_points):
    inducing_points = inducing_points
    variational_distribution = CholeskyVariationalDistribution(inducing_points.size(-2),
                                                               batch_shape=torch.Size([n_tasks]))

    variational_strategy = gpytorch.variational.IndependentMultitaskVariationalStrategy(
                                                   VariationalStrategy(self, inducing_points,
                                                       variational_distribution,
                                                       learn_inducing_locations=True),
                                                num_tasks=n_tasks
                                             )

    super(StatePredictor, self).__init__(variational_strategy)
    self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([n_tasks]))
    self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel(batch_shape=torch.Size([n_tasks]),
                                                                                ard_num_dims=X_train_env0_tensor.size(-1)),
                                                    batch_shape = torch.Size([n_tasks])
                                                  )

  def forward(self, x):
    mean_x = self.mean_module(x)
    covar_x = self.covar_module(x)
    return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

model_gp_env0 = StatePredictor(inducing_points)
likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=n_tasks)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Save the scaler
import pickle

with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
num_epochs = 3000


model_gp_env0 = model_gp_env0.to(device)
likelihood = likelihood.to(device)

model_gp_env0.train()
likelihood.train()

optimizer = torch.optim.Adam([
    {"params": model_gp_env0.parameters()},
    {"params": likelihood.parameters()},
], lr=0.05)

#scheduler = MultiStepLR(optimizer, milestones=[500, 1000, 1500], gamma=0.5)
scheduler = ExponentialLR(optimizer, gamma=1-1e-3)

# loss object: VariationalELBO
mll = gpytorch.mlls.VariationalELBO(likelihood, model_gp_env0,
                                    num_data=y_train_env0_tensor.size(0))


best_loss_test = np.inf
losses_train = []
losses_test = []
#epochs_iter = tqdm.notebook.tqdm(range(num_epochs), desc="Epoch")
for i in range(num_epochs):
  model_gp_env0.train()
  likelihood.train()
  for _, (x_batch, y_batch) in enumerate(train_loader):
    x_batch = x_batch.to(device)
    y_batch = y_batch.to(device)
    optimizer.zero_grad()
    output = model_gp_env0(x_batch)
    loss = -mll(output, y_batch)
    loss.backward()
    optimizer.step()
    scheduler.step()
    losses_train.append(loss.item())


  with torch.no_grad():
    model_gp_env0.eval()
    likelihood.eval()
    for _, (x_batch, y_batch) in enumerate(test_loader):
      x_batch = x_batch.to(device)
      y_batch = y_batch.to(device)
      output = model_gp_env0(x_batch)
      loss = -mll(output, y_batch)
      losses_test.append(loss.item())
  print(f"""Iteration: {i+1}, train loss: {np.mean(losses_train)},
                     test loss: {np.mean(losses_test)}""")

  if np.mean(losses_test) < best_loss_test:
      torch.save(model_gp_env0, "model_gp_env0.pth")
      best_loss_test = np.mean(losses_test)
      print("Best model so far!")
# Out:
# Streaming output truncated to the last 5000 lines.
#                      test loss: -9.120781484912003
# Best model so far!
# Iteration: 1335, train loss: -9.120979836266383,
#                      test loss: -9.120815822354864
# Best model so far!
# Iteration: 1336, train loss: -9.121017815987127,
#                      test loss: -9.120850108394366
# Best model so far!
# Iteration: 1337, train loss: -9.121055738965854,
#                      test loss: -9.120884343145852
# Best model so far!
# Iteration: 1338, train loss: -9.121093605044688,
#                      test loss: -9.120918526724315
# Best model so far!
# Iteration: 1339, train loss: -9.121131414671611,
#                      test loss: -9.12095265924441
# Best model so far!
# Iteration: 1340, train loss: -9.121169167937426,
#                      test loss: -9.120986740820443
# Best model so far!
# Iteration: 1341, train loss: -9.121206864825986,
#                      test loss: -9.121020771566387
# Best model so far!
# Iteration: 1342, train loss: -9.12124450567651,
#                      test loss: -9.121054751595867
# Best model so far!
# Iteration: 1343, train loss: -9.121282090365641,
#                      test loss: -9.121088681022178
# Best model so far!
# Iteration: 1344, train loss: -9.121319619125176,
#                      test loss: -9.121122559958271
# Best model so far!
# Iteration: 1345, train loss: -9.121357091938052,
#                      test loss: -9.121156388516763
# Best model so far!
# Iteration: 1346, train loss: -9.12139450917695,
#                      test loss: -9.121190166809939
# Best model so far!
# Iteration: 1347, train loss: -9.121431870894844,
#                      test loss: -9.121223894949745
# Best model so far!
# Iteration: 1348, train loss: -9.121469177144547,
#                      test loss: -9.121257573047803
# Best model so far!
# Iteration: 1349, train loss: -9.12150642812011,
#                      test loss: -9.121291201215394
# Best model so far!
# Iteration: 1350, train loss: -9.121543623767758,
#                      test loss: -9.12132477956348
# Best model so far!
# Iteration: 1351, train loss: -9.121580764633892,
#                      test loss: -9.121358308202685
# Best model so far!
# Iteration: 1352, train loss: -9.12161785045211,
#                      test loss: -9.121391787243313
# Best model so far!
# Iteration: 1353, train loss: -9.12165488137971,
#                      test loss: -9.121425216795336
# Best model so far!
# Iteration: 1354, train loss: -9.121691857714397,
#                      test loss: -9.121458596968404
# Best model so far!
# Iteration: 1355, train loss: -9.121728779401087,
#                      test loss: -9.121491927871844
# Best model so far!
# Iteration: 1356, train loss: -9.121765646595847,
#                      test loss: -9.121525209614662
# Best model so far!
# Iteration: 1357, train loss: -9.121802459454285,
#                      test loss: -9.121558442305535
# Best model so far!
# Iteration: 1358, train loss: -9.12183921813155,
#                      test loss: -9.121591626052828
# Best model so far!
# Iteration: 1359, train loss: -9.121875922466547,
#                      test loss: -9.121624760964584
# Best model so far!
# Iteration: 1360, train loss: -9.121912573175196,
#                      test loss: -9.12165784714853
# Best model so far!
# Iteration: 1361, train loss: -9.121949169955275,
#                      test loss: -9.121690884712073
# Best model so far!
# Iteration: 1362, train loss: -9.12198571292557,
#                      test loss: -9.121723873762306
# Best model so far!
# Iteration: 1363, train loss: -9.122022202344453,
#                      test loss: -9.12175681440601
# Best model so far!
# Iteration: 1364, train loss: -9.122058638154913,
#                      test loss: -9.12178970674965
# Best model so far!
# Iteration: 1365, train loss: -9.122095020719302,
#                      test loss: -9.12182255089938
# Best model so far!
# Iteration: 1366, train loss: -9.122131349980023,
#                      test loss: -9.121855346961043
# Best model so far!
# Iteration: 1367, train loss: -9.12216762598429,
#                      test loss: -9.121888095040172
# Best model so far!
# Iteration: 1368, train loss: -9.122203849023174,
#                      test loss: -9.121920795241993
# Best model so far!
# Iteration: 1369, train loss: -9.12224001900376,
#                      test loss: -9.121953447671421
# Best model so far!
# Iteration: 1370, train loss: -9.122276136355481,
#                      test loss: -9.12198605243307
# Best model so far!
# Iteration: 1371, train loss: -9.122312201123941,
#                      test loss: -9.122018609631244
# Best model so far!
# Iteration: 1372, train loss: -9.122348213250342,
#                      test loss: -9.122051119369946
# Best model so far!
# Iteration: 1373, train loss: -9.122384172919167,
#                      test loss: -9.122083581752875
# Best model so far!
# Iteration: 1374, train loss: -9.122420080314361,
#                      test loss: -9.122115996883426
# Best model so far!
# Iteration: 1375, train loss: -9.122455935341899,
#                      test loss: -9.122148364864696
# Best model so far!
# Iteration: 1376, train loss: -9.122491738115956,
#                      test loss: -9.122180685799481
# Best model so far!
# Iteration: 1377, train loss: -9.122527489096662,
#                      test loss: -9.122212959790282
# Best model so far!
# Iteration: 1378, train loss: -9.122563187912322,
#                      test loss: -9.122245186939296
# Best model so far!
# Iteration: 1379, train loss: -9.122598835195099,
#                      test loss: -9.122277367348426
# Best model so far!
# Iteration: 1380, train loss: -9.122634430849702,
#                      test loss: -9.122309501119283
# Best model so far!
# Iteration: 1381, train loss: -9.122669974815642,
#                      test loss: -9.122341588353178
# Best model so far!
# Iteration: 1382, train loss: -9.122705467481149,
#                      test loss: -9.122373629151136
# Best model so far!
# Iteration: 1383, train loss: -9.122740908750634,
#                      test loss: -9.122405623613883
# Best model so far!
# Iteration: 1384, train loss: -9.122776298735504,
#                      test loss: -9.122437571841857
# Best model so far!
# Iteration: 1385, train loss: -9.122811637684562,
#                      test loss: -9.122469473935206
# Best model so far!
# Iteration: 1386, train loss: -9.122846925708272,
#                      test loss: -9.122501329993788
# Best model so far!
# Iteration: 1387, train loss: -9.122882162744888,
#                      test loss: -9.122533140117175
# Best model so far!
# Iteration: 1388, train loss: -9.12291734893897,
#                      test loss: -9.122564904404648
# Best model so far!
# Iteration: 1389, train loss: -9.122952484434652,
#                      test loss: -9.122596622955207
# Best model so far!
# Iteration: 1390, train loss: -9.122987569478582,
#                      test loss: -9.122628295867564
# Best model so far!
# Iteration: 1391, train loss: -9.123022604111005,
#                      test loss: -9.122659923240146
# Best model so far!
# Iteration: 1392, train loss: -9.123057588543334,
#                      test loss: -9.122691505171101
# Best model so far!
# Iteration: 1393, train loss: -9.123092522507143,
#                      test loss: -9.122723041758293
# Best model so far!
# Iteration: 1394, train loss: -9.123127406384693,
#                      test loss: -9.122754533099307
# Best model so far!
# Iteration: 1395, train loss: -9.123162240249515,
#                      test loss: -9.122785979291445
# Best model so far!
# Iteration: 1396, train loss: -9.123197024209087,
#                      test loss: -9.12281738043173
# Best model so far!
# Iteration: 1397, train loss: -9.123231758472977,
#                      test loss: -9.12284873661691
# Best model so far!
# Iteration: 1398, train loss: -9.123266443045502,
#                      test loss: -9.12288004794346
# Best model so far!
# Iteration: 1399, train loss: -9.123301077965051,
#                      test loss: -9.122911314507567
# Best model so far!
# Iteration: 1400, train loss: -9.123335663508325,
#                      test loss: -9.122942536405155
# Best model so far!
# Iteration: 1401, train loss: -9.123370199576838,
#                      test loss: -9.122973713731868
# Best model so far!
# Iteration: 1402, train loss: -9.12340468634448,
#                      test loss: -9.123004846583079
# Best model so far!
# Iteration: 1403, train loss: -9.123439124120592,
#                      test loss: -9.12303593505389
# Best model so far!
# Iteration: 1404, train loss: -9.123473512704194,
#                      test loss: -9.12306697923913
# Best model so far!
# Iteration: 1405, train loss: -9.123507852370013,
#                      test loss: -9.123097979233359
# Best model so far!
# Iteration: 1406, train loss: -9.123542143052854,
#                      test loss: -9.123128935130866
# Best model so far!
# Iteration: 1407, train loss: -9.12357638509439,
#                      test loss: -9.123159847025677
# Best model so far!
# Iteration: 1408, train loss: -9.12361057842893,
#                      test loss: -9.123190715011548
# Best model so far!
# Iteration: 1409, train loss: -9.123644723397078,
#                      test loss: -9.123221539181966
# Best model so far!
# Iteration: 1410, train loss: -9.123678819797371,
#                      test loss: -9.123252319630156
# Best model so far!
# Iteration: 1411, train loss: -9.12371286783446,
#                      test loss: -9.123283056449079
# Best model so far!
# Iteration: 1412, train loss: -9.123746867847487,
#                      test loss: -9.123313749731432
# Best model so far!
# Iteration: 1413, train loss: -9.123780819600954,
#                      test loss: -9.123344399569648
# Best model so far!
# Iteration: 1414, train loss: -9.123814723399583,
#                      test loss: -9.1233750060559
# Best model so far!
# Iteration: 1415, train loss: -9.123848579345047,
#                      test loss: -9.1234055692821
# Best model so far!
# Iteration: 1416, train loss: -9.123882387505054,
#                      test loss: -9.123436089339902
# Best model so far!
# Iteration: 1417, train loss: -9.123916147745213,
#                      test loss: -9.123466566320701
# Best model so far!
# Iteration: 1418, train loss: -9.123949860469557,
#                      test loss: -9.12349700031563
# Best model so far!
# Iteration: 1419, train loss: -9.123983525812141,
#                      test loss: -9.12352739141557
# Best model so far!
# Iteration: 1420, train loss: -9.12401714367159,
#                      test loss: -9.123557739711144
# Best model so far!
# Iteration: 1421, train loss: -9.12405071414815,
#                      test loss: -9.123588045292719
# Best model so far!
# Iteration: 1422, train loss: -9.124084237341785,
#                      test loss: -9.12361830825041
# Best model so far!
# Iteration: 1423, train loss: -9.124117713452703,
#                      test loss: -9.12364852867408
# Best model so far!
# Iteration: 1424, train loss: -9.124151142479642,
#                      test loss: -9.123678706653333
# Best model so far!
# Iteration: 1425, train loss: -9.124184524588646,
#                      test loss: -9.123708842277527
# Best model so far!
# Iteration: 1426, train loss: -9.12421785997874,
#                      test loss: -9.12373893563577
# Best model so far!
# Iteration: 1427, train loss: -9.124251148681312,
#                      test loss: -9.123768986816915
# Best model so far!
# Iteration: 1428, train loss: -9.12428439076105,
#                      test loss: -9.12379899590957
# Best model so far!
# Iteration: 1429, train loss: -9.124317586148988,
#                      test loss: -9.123828963002097
# Best model so far!
# Iteration: 1430, train loss: -9.124350735176504,
#                      test loss: -9.123858888182607
# Best model so far!
# Iteration: 1431, train loss: -9.124383837974108,
#                      test loss: -9.123888771538965
# Best model so far!
# Iteration: 1432, train loss: -9.124416894572052,
#                      test loss: -9.123918613158791
# Best model so far!
# Iteration: 1433, train loss: -9.124449904867404,
#                      test loss: -9.123948413129462
# Best model so far!
# Iteration: 1434, train loss: -9.12448286922305,
#                      test loss: -9.12397817153811
# Best model so far!
# Iteration: 1435, train loss: -9.124515787668571,
#                      test loss: -9.124007888471624
# Best model so far!
# Iteration: 1436, train loss: -9.124548660200265,
#                      test loss: -9.12403756401665
# Best model so far!
# Iteration: 1437, train loss: -9.124581486980347,
#                      test loss: -9.124067198259597
# Best model so far!
# Iteration: 1438, train loss: -9.124614268137428,
#                      test loss: -9.124096791286627
# Best model so far!
# Iteration: 1439, train loss: -9.124647003733486,
#                      test loss: -9.12412634318367
# Best model so far!
# Iteration: 1440, train loss: -9.124679693764095,
#                      test loss: -9.124155854036411
# Best model so far!
# Iteration: 1441, train loss: -9.124712338390301,
#                      test loss: -9.1241853239303
# Best model so far!
# Iteration: 1442, train loss: -9.124744937838837,
#                      test loss: -9.12421475295055
# Best model so far!
# Iteration: 1443, train loss: -9.124777492170583,
#                      test loss: -9.124244141182135
# Best model so far!
# Iteration: 1444, train loss: -9.12481000131416,
#                      test loss: -9.1242734887098
# Best model so far!
# Iteration: 1445, train loss: -9.124842465429383,
#                      test loss: -9.12430279561805
# Best model so far!
# Iteration: 1446, train loss: -9.124874884675625,
#                      test loss: -9.124332061991158
# Best model so far!
# Iteration: 1447, train loss: -9.124907259112957,
#                      test loss: -9.12436128791316
# Best model so far!
# Iteration: 1448, train loss: -9.124939588768354,
#                      test loss: -9.12439047346787
# Best model so far!
# Iteration: 1449, train loss: -9.124971873833257,
#                      test loss: -9.124419618738857
# Best model so far!
# Iteration: 1450, train loss: -9.125004114531462,
#                      test loss: -9.124448723809472
# Best model so far!
# Iteration: 1451, train loss: -9.125036310658937,
#                      test loss: -9.12447778876283
# Best model so far!
# Iteration: 1452, train loss: -9.125068462439126,
#                      test loss: -9.124506813681815
# Best model so far!
# Iteration: 1453, train loss: -9.12510056993078,
#                      test loss: -9.124535798649088
# Best model so far!
# Iteration: 1454, train loss: -9.125132633389251,
#                      test loss: -9.124564743747081
# Best model so far!
# Iteration: 1455, train loss: -9.125164652741466,
#                      test loss: -9.124593649057998
# Best model so far!
# Iteration: 1456, train loss: -9.125196628111055,
#                      test loss: -9.124622514663816
# Best model so far!
# Iteration: 1457, train loss: -9.125228559523125,
#                      test loss: -9.124651340646292
# Best model so far!
# Iteration: 1458, train loss: -9.125260447231645,
#                      test loss: -9.124680127086954
# Best model so far!
# Iteration: 1459, train loss: -9.125292291097704,
#                      test loss: -9.124708874067107
# Best model so far!
# Iteration: 1460, train loss: -9.125324091374688,
#                      test loss: -9.124737581667835
# Best model so far!
# Iteration: 1461, train loss: -9.125355848119467,
#                      test loss: -9.12476624997
# Best model so far!
# Iteration: 1462, train loss: -9.125387561356135,
#                      test loss: -9.12479487905424
# Best model so far!
# Iteration: 1463, train loss: -9.125419231304283,
#                      test loss: -9.124823469000978
# Best model so far!
# Iteration: 1464, train loss: -9.125450857922331,
#                      test loss: -9.12485201989041
# Best model so far!
# Iteration: 1465, train loss: -9.125482441266465,
#                      test loss: -9.12488053180252
# Best model so far!
# Iteration: 1466, train loss: -9.125513981717974,
#                      test loss: -9.124909004817068
# Best model so far!
# Iteration: 1467, train loss: -9.125545479202055,
#                      test loss: -9.1249374390136
# Best model so far!
# Iteration: 1468, train loss: -9.125576933644101,
#                      test loss: -9.124965834471446
# Best model so far!
# Iteration: 1469, train loss: -9.125608345359238,
#                      test loss: -9.124994191269716
# Best model so far!
# Iteration: 1470, train loss: -9.125639714337346,
#                      test loss: -9.125022509487307
# Best model so far!
# Iteration: 1471, train loss: -9.125671040730419,
#                      test loss: -9.125050789202906
# Best model so far!
# Iteration: 1472, train loss: -9.125702324528064,
#                      test loss: -9.125079030494975
# Best model so far!
# Iteration: 1473, train loss: -9.125733566011263,
#                      test loss: -9.125107233441774
# Best model so far!
# Iteration: 1474, train loss: -9.125764764877943,
#                      test loss: -9.125135398121346
# Best model so far!
# Iteration: 1475, train loss: -9.125795921441073,
#                      test loss: -9.125163524611521
# Best model so far!
# Iteration: 1476, train loss: -9.125827035915863,
#                      test loss: -9.125191612989921
# Best model so far!
# Iteration: 1477, train loss: -9.12585810816181,
#                      test loss: -9.125219663333958
# Best model so far!
# Iteration: 1478, train loss: -9.125889138490464,
#                      test loss: -9.125247675720829
# Best model so far!
# Iteration: 1479, train loss: -9.12592012685789,
#                      test loss: -9.125275650227529
# Best model so far!
# Iteration: 1480, train loss: -9.125951073284707,
#                      test loss: -9.125303586930842
# Best model so far!
# Iteration: 1481, train loss: -9.125981977920267,
#                      test loss: -9.125331485907344
# Best model so far!
# Iteration: 1482, train loss: -9.126012840688288,
#                      test loss: -9.125359347233406
# Best model so far!
# Iteration: 1483, train loss: -9.12604366196285,
#                      test loss: -9.12538717098519
# Best model so far!
# Iteration: 1484, train loss: -9.126074441667173,
#                      test loss: -9.125414957238657
# Best model so far!
# Iteration: 1485, train loss: -9.126105179853129,
#                      test loss: -9.125442706069562
# Best model so far!
# Iteration: 1486, train loss: -9.126135876604536,
#                      test loss: -9.125470417553451
# Best model so far!
# Iteration: 1487, train loss: -9.126166532197391,
#                      test loss: -9.125498091765675
# Best model so far!
# Iteration: 1488, train loss: -9.1261971465224,
#                      test loss: -9.125525728781376
# Best model so far!
# Iteration: 1489, train loss: -9.126227719758782,
#                      test loss: -9.1255533286755
# Best model so far!
# Iteration: 1490, train loss: -9.12625825205327,
#                      test loss: -9.125580891522786
# Best model so far!
# Iteration: 1491, train loss: -9.126288743456264,
#                      test loss: -9.125608417397773
# Best model so far!
# Iteration: 1492, train loss: -9.126319193698425,
#                      test loss: -9.125635906374805
# Best model so far!
# Iteration: 1493, train loss: -9.126349603405412,
#                      test loss: -9.125663358528024
# Best model so far!
# Iteration: 1494, train loss: -9.126379972339453,
#                      test loss: -9.125690773931373
# Best model so far!
# Iteration: 1495, train loss: -9.12641030048668,
#                      test loss: -9.125718152658596
# Best model so far!
# Iteration: 1496, train loss: -9.126440588247627,
#                      test loss: -9.125745494783244
# Best model so far!
# Iteration: 1497, train loss: -9.126470835575816,
#                      test loss: -9.125772800378666
# Best model so far!
# Iteration: 1498, train loss: -9.12650104252039,
#                      test loss: -9.12580006951802
# Best model so far!
# Iteration: 1499, train loss: -9.126531209225789,
#                      test loss: -9.125827302274265
# Best model so far!
# Iteration: 1500, train loss: -9.126561335549969,
#                      test loss: -9.12585449872017
# Best model so far!
# Iteration: 1501, train loss: -9.126591421764246,
#                      test loss: -9.125881658928304
# Best model so far!
# Iteration: 1502, train loss: -9.126621467853493,
#                      test loss: -9.125908782971049
# Best model so far!
# Iteration: 1503, train loss: -9.126651474151602,
#                      test loss: -9.125935870920589
# Best model so far!
# Iteration: 1504, train loss: -9.12668144026238,
#                      test loss: -9.12596292284892
# Best model so far!
# Iteration: 1505, train loss: -9.1267113667095,
#                      test loss: -9.125989938827844
# Best model so far!
# Iteration: 1506, train loss: -9.126741253287014,
#                      test loss: -9.126016918928975
# Best model so far!
# Iteration: 1507, train loss: -9.126771100264138,
#                      test loss: -9.126043863223734
# Best model so far!
# Iteration: 1508, train loss: -9.12680090762479,
#                      test loss: -9.126070771783354
# Best model so far!
# Iteration: 1509, train loss: -9.12683067557413,
#                      test loss: -9.126097644678879
# Best model so far!
# Iteration: 1510, train loss: -9.12686040419046,
#                      test loss: -9.126124481981163
# Best model so far!
# Iteration: 1511, train loss: -9.126890093362524,
#                      test loss: -9.126151283760878
# Best model so far!
# Iteration: 1512, train loss: -9.126919743200123,
#                      test loss: -9.126178050088503
# Best model so far!
# Iteration: 1513, train loss: -9.126949353907312,
#                      test loss: -9.126204781034335
# Best model so far!
# Iteration: 1514, train loss: -9.126978925530137,
#                      test loss: -9.12623147666848
# Best model so far!
# Iteration: 1515, train loss: -9.127008458177464,
#                      test loss: -9.126258137060864
# Best model so far!
# Iteration: 1516, train loss: -9.127037951957876,
#                      test loss: -9.126284762281227
# Best model so far!
# Iteration: 1517, train loss: -9.12706740679107,
#                      test loss: -9.126311352399123
# Best model so far!
# Iteration: 1518, train loss: -9.127096822722606,
#                      test loss: -9.126337907483926
# Best model so far!
# Iteration: 1519, train loss: -9.127126199797923,
#                      test loss: -9.126364427604827
# Best model so far!
# Iteration: 1520, train loss: -9.127155538313305,
#                      test loss: -9.12639091283083
# Best model so far!
# Iteration: 1521, train loss: -9.12718483837616,
#                      test loss: -9.126417363230763
# Best model so far!
# Iteration: 1522, train loss: -9.12721409981164,
#                      test loss: -9.126443778873274
# Best model so far!
# Iteration: 1523, train loss: -9.12724332300893,
#                      test loss: -9.126470159826823
# Best model so far!
# Iteration: 1524, train loss: -9.12727250773041,
#                      test loss: -9.1264965061597
# Best model so far!
# Iteration: 1525, train loss: -9.127301654239384,
#                      test loss: -9.126522817940009
# Best model so far!
# Iteration: 1526, train loss: -9.127330762423485,
#                      test loss: -9.126549095235678
# Best model so far!
# Iteration: 1527, train loss: -9.127359832295557,
#                      test loss: -9.126575338114456
# Best model so far!
# Iteration: 1528, train loss: -9.127388864367711,
#                      test loss: -9.126601546643917
# Best model so far!
# Iteration: 1529, train loss: -9.12741785824632,
#                      test loss: -9.126627720891454
# Best model so far!
# Iteration: 1530, train loss: -9.127446814380264,
#                      test loss: -9.126653860924291
# Best model so far!
# Iteration: 1531, train loss: -9.127475732750066,
#                      test loss: -9.126679966809467
# Best model so far!
# Iteration: 1532, train loss: -9.127504613305176,
#                      test loss: -9.126706038613854
# Best model so far!
# Iteration: 1533, train loss: -9.127533456181807,
#                      test loss: -9.126732076404146
# Best model so far!
# Iteration: 1534, train loss: -9.127562261453642,
#                      test loss: -9.126758080246862
# Best model so far!
# Iteration: 1535, train loss: -9.12759102919418,
#                      test loss: -9.12678405020835
# Best model so far!
# Iteration: 1536, train loss: -9.127619759445679,
#                      test loss: -9.126809986354782
# Best model so far!
# Iteration: 1537, train loss: -9.127648452343358,
#                      test loss: -9.126835888752165
# Best model so far!
# Iteration: 1538, train loss: -9.127677107929077,
#                      test loss: -9.126861757466324
# Best model so far!
# Iteration: 1539, train loss: -9.127705726213602,
#                      test loss: -9.126887592562923
# Best model so far!
# Iteration: 1540, train loss: -9.127734307455377,
#                      test loss: -9.126913394107447
# Best model so far!
# Iteration: 1541, train loss: -9.127762851602743,
#                      test loss: -9.126939162165217
# Best model so far!
# Iteration: 1542, train loss: -9.127791358604176,
#                      test loss: -9.12696489680138
# Best model so far!
# Iteration: 1543, train loss: -9.127819828686413,
#                      test loss: -9.12699059808092
# Best model so far!
# Iteration: 1544, train loss: -9.12784826204472,
#                      test loss: -9.127016266068646
# Best model so far!
# Iteration: 1545, train loss: -9.127876658503503,
#                      test loss: -9.127041900829203
# Best model so far!
# Iteration: 1546, train loss: -9.127905018165205,
#                      test loss: -9.12706750242707
# Best model so far!
# Iteration: 1547, train loss: -9.127933341193657,
#                      test loss: -9.127093070926556
# Best model so far!
# Iteration: 1548, train loss: -9.127961627629048,
#                      test loss: -9.127118606391804
# Best model so far!
# Iteration: 1549, train loss: -9.127989877449899,
#                      test loss: -9.127144108886792
# Best model so far!
# Iteration: 1550, train loss: -9.12801809091166,
#                      test loss: -9.127169578475337
# Best model so far!
# Iteration: 1551, train loss: -9.128046267807964,
#                      test loss: -9.127195015221085
# Best model so far!
# Iteration: 1552, train loss: -9.128074408578176,
#                      test loss: -9.127220419187521
# Best model so far!
# Iteration: 1553, train loss: -9.128102512985045,
#                      test loss: -9.127245790437968
# Best model so far!
# Iteration: 1554, train loss: -9.128130581344243,
#                      test loss: -9.12727112903558
# Best model so far!
# Iteration: 1555, train loss: -9.128158613694652,
#                      test loss: -9.127296435043359
# Best model so far!
# Iteration: 1556, train loss: -9.128186610075053,
#                      test loss: -9.127321708524136
# Best model so far!
# Iteration: 1557, train loss: -9.128214570309748,
#                      test loss: -9.12734694954058
# Best model so far!
# Iteration: 1558, train loss: -9.128242494713184,
#                      test loss: -9.12737215815521
# Best model so far!
# Iteration: 1559, train loss: -9.128270383231966,
#                      test loss: -9.12739733443037
# Best model so far!
# Iteration: 1560, train loss: -9.128298235965671,
#                      test loss: -9.127422478428254
# Best model so far!
# Iteration: 1561, train loss: -9.128326053166354,
#                      test loss: -9.127447590210894
# Best model so far!
# Iteration: 1562, train loss: -9.128353834749621,
#                      test loss: -9.127472669840165
# Best model so far!
# Iteration: 1563, train loss: -9.128381580722822,
#                      test loss: -9.127497717377778
# Best model so far!
# Iteration: 1564, train loss: -9.128409291276217,
#                      test loss: -9.127522732885293
# Best model so far!
# Iteration: 1565, train loss: -9.128436966355824,
#                      test loss: -9.127547716424107
# Best model so far!
# Iteration: 1566, train loss: -9.128464606120954,
#                      test loss: -9.127572668055464
# Best model so far!
# Iteration: 1567, train loss: -9.12849221054792,
#                      test loss: -9.127597587840452
# Best model so far!
# Iteration: 1568, train loss: -9.128519779673928,
#                      test loss: -9.127622475839999
# Best model so far!
# Iteration: 1569, train loss: -9.128547313718428,
#                      test loss: -9.127647332114881
# Best model so far!
# Iteration: 1570, train loss: -9.12857481277883,
#                      test loss: -9.127672156725719
# Best model so far!
# Iteration: 1571, train loss: -9.128602276770172,
#                      test loss: -9.127696949732979
# Best model so far!
# Iteration: 1572, train loss: -9.128629705820051,
#                      test loss: -9.127721711196973
# Best model so far!
# Iteration: 1573, train loss: -9.128657100055733,
#                      test loss: -9.127746441177859
# Best model so far!
# Iteration: 1574, train loss: -9.128684459422393,
#                      test loss: -9.127771139735643
# Best model so far!
# Iteration: 1575, train loss: -9.128711784016724,
#                      test loss: -9.127795806930179
# Best model so far!
# Iteration: 1576, train loss: -9.12873907390492,
#                      test loss: -9.127820442821168
# Best model so far!
# Iteration: 1577, train loss: -9.12876632927395,
#                      test loss: -9.127845047468162
# Best model so far!
# Iteration: 1578, train loss: -9.128793550038347,
#                      test loss: -9.127869620930559
# Best model so far!
# Iteration: 1579, train loss: -9.12882073638466,
#                      test loss: -9.127894163267609
# Best model so far!
# Iteration: 1580, train loss: -9.128847888197155,
#                      test loss: -9.127918674538407
# Best model so far!
# Iteration: 1581, train loss: -9.128875005812809,
#                      test loss: -9.127943154801907
# Best model so far!
# Iteration: 1582, train loss: -9.128902089145763,
#                      test loss: -9.127967604116906
# Best model so far!
# Iteration: 1583, train loss: -9.128929138200743,
#                      test loss: -9.127992022542056
# Best model so far!
# Iteration: 1584, train loss: -9.128956153193187,
#                      test loss: -9.128016410135862
# Best model so far!
# Iteration: 1585, train loss: -9.128983134007058,
#                      test loss: -9.128040766956678
# Best model so far!
# Iteration: 1586, train loss: -9.12901008076714,
#                      test loss: -9.128065093062714
# Best model so far!
# Iteration: 1587, train loss: -9.129036993597897,
#                      test loss: -9.128089388512032
# Best model so far!
# Iteration: 1588, train loss: -9.129063872593456,
#                      test loss: -9.128113653362549
# Best model so far!
# Iteration: 1589, train loss: -9.129090717637647,
#                      test loss: -9.12813788767203
# Best model so far!
# Iteration: 1590, train loss: -9.129117529034446,
#                      test loss: -9.128162091498105
# Best model so far!
# Iteration: 1591, train loss: -9.12914430666747,
#                      test loss: -9.12818626489825
# Best model so far!
# Iteration: 1592, train loss: -9.129171050720158,
#                      test loss: -9.128210407929803
# Best model so far!
# Iteration: 1593, train loss: -9.129197761136016,
#                      test loss: -9.128234520649954
# Best model so far!
# Iteration: 1594, train loss: -9.129224438008261,
#                      test loss: -9.128258603115752
# Best model so far!
# Iteration: 1595, train loss: -9.12925108145978,
#                      test loss: -9.1282826553841
# Best model so far!
# Iteration: 1596, train loss: -9.129277691523512,
#                      test loss: -9.12830667751176
# Best model so far!
# Iteration: 1597, train loss: -9.129304268232325,
#                      test loss: -9.128330669555353
# Best model so far!
# Iteration: 1598, train loss: -9.129330811618992,
#                      test loss: -9.128354631571359
# Best model so far!
# Iteration: 1599, train loss: -9.129357321805678,
#                      test loss: -9.12837856361611
# Best model so far!
# Iteration: 1600, train loss: -9.129383798914233,
#                      test loss: -9.128402465745806
# Best model so far!
# Iteration: 1601, train loss: -9.129410242827943,
#                      test loss: -9.128426338016503
# Best model so far!
# Iteration: 1602, train loss: -9.129436653906616,
#                      test loss: -9.128450180484114
# Best model so far!
# Iteration: 1603, train loss: -9.129463032152213,
#                      test loss: -9.128473993204418
# Best model so far!
# Iteration: 1604, train loss: -9.129489377418045,
#                      test loss: -9.12849777623305
# Best model so far!
# Iteration: 1605, train loss: -9.129515689944013,
#                      test loss: -9.128521529625509
# Best model so far!
# Iteration: 1606, train loss: -9.129541969494367,
#                      test loss: -9.128545253437157
# Best model so far!
# Iteration: 1607, train loss: -9.129568216368044,
#                      test loss: -9.128568947723213
# Best model so far!
# Iteration: 1608, train loss: -9.129594430626012,
#                      test loss: -9.128592612538764
# Best model so far!
# Iteration: 1609, train loss: -9.129620612358716,
#                      test loss: -9.12861624793876
# Best model so far!
# Iteration: 1610, train loss: -9.129646761419442,
#                      test loss: -9.12863985397801
# Best model so far!
# Iteration: 1611, train loss: -9.129672878135421,
#                      test loss: -9.128663430711189
# Best model so far!
# Iteration: 1612, train loss: -9.129698962330206,
#                      test loss: -9.128686978192839
# Best model so far!
# Iteration: 1613, train loss: -9.12972501430078,
#                      test loss: -9.128710496477362
# Best model so far!
# Iteration: 1614, train loss: -9.12975103398886,
#                      test loss: -9.12873398561903
# Best model so far!
# Iteration: 1615, train loss: -9.129777021336315,
#                      test loss: -9.12875744567198
# Best model so far!
# Iteration: 1616, train loss: -9.129802976580224,
#                      test loss: -9.128780876690207
# Best model so far!
# Iteration: 1617, train loss: -9.129828899839131,
#                      test loss: -9.128804278727586
# Best model so far!
# Iteration: 1618, train loss: -9.12985479099551,
#                      test loss: -9.128827651837847
# Best model so far!
# Iteration: 1619, train loss: -9.129880650108852,
#                      test loss: -9.128850996074593
# Best model so far!
# Iteration: 1620, train loss: -9.129906477267928,
#                      test loss: -9.128874311491295
# Best model so far!
# Iteration: 1621, train loss: -9.129932272531876,
#                      test loss: -9.128897598141288
# Best model so far!
# Iteration: 1622, train loss: -9.12995803613608,
#                      test loss: -9.12892085607778
# Best model so far!
# Iteration: 1623, train loss: -9.129983767992154,
#                      test loss: -9.128944085353844
# Best model so far!
# Iteration: 1624, train loss: -9.130009468158752,
#                      test loss: -9.128967286022426
# Best model so far!
# Iteration: 1625, train loss: -9.130035136577,
#                      test loss: -9.128990458136338
# Best model so far!
# Iteration: 1626, train loss: -9.130060773422779,
#                      test loss: -9.129013601748266
# Best model so far!
# Iteration: 1627, train loss: -9.130086378930148,
#                      test loss: -9.129036716910763
# Best model so far!
# Iteration: 1628, train loss: -9.130111952863961,
#                      test loss: -9.129059803676254
# Best model so far!
# Iteration: 1629, train loss: -9.130137495457998,
#                      test loss: -9.129082862097036
# Best model so far!
# Iteration: 1630, train loss: -9.130163006711426,
#                      test loss: -9.129105892225278
# Best model so far!
# Iteration: 1631, train loss: -9.130188486623423,
#                      test loss: -9.129128894113018
# Best model so far!
# Iteration: 1632, train loss: -9.13021393542691,
#                      test loss: -9.12915186781217
# Best model so far!
# Iteration: 1633, train loss: -9.130239353003835,
#                      test loss: -9.12917481337452
# Best model so far!
# Iteration: 1634, train loss: -9.130264739469895,
#                      test loss: -9.129197730851727
# Best model so far!
# Iteration: 1635, train loss: -9.13029009491134,
#                      test loss: -9.129220620295323
# Best model so far!
# Iteration: 1636, train loss: -9.130315419181033,
#                      test loss: -9.129243481756713
# Best model so far!
# Iteration: 1637, train loss: -9.130340712481743,
#                      test loss: -9.12926631528718
# Best model so far!
# Iteration: 1638, train loss: -9.13036597510308,
#                      test loss: -9.129289120937878
# Best model so far!
# Iteration: 1639, train loss: -9.130391206693892,
#                      test loss: -9.129311898759838
# Best model so far!
# Iteration: 1640, train loss: -9.130416407630774,
#                      test loss: -9.129334648803967
# Best model so far!
# Iteration: 1641, train loss: -9.130441577969764,
#                      test loss: -9.129357371121046
# Best model so far!
# Iteration: 1642, train loss: -9.130466717505406,
#                      test loss: -9.129380065761733
# Best model so far!
# Iteration: 1643, train loss: -9.130491826439059,
#                      test loss: -9.129402732776565
# Best model so far!
# Iteration: 1644, train loss: -9.130516904768553,
#                      test loss: -9.129425372215954
# Best model so far!
# Iteration: 1645, train loss: -9.130541952723625,
#                      test loss: -9.129447984130186
# Best model so far!
# Iteration: 1646, train loss: -9.130566970098911,
#                      test loss: -9.129470568569433
# Best model so far!
# Iteration: 1647, train loss: -9.130591957152776,
#                      test loss: -9.129493125583739
# Best model so far!
# Iteration: 1648, train loss: -9.130616913824676,
#                      test loss: -9.129515655223027
# Best model so far!
# Iteration: 1649, train loss: -9.13064184031447,
#                      test loss: -9.1295381575371
# Best model so far!
# Iteration: 1650, train loss: -9.130666736561437,
#                      test loss: -9.129560632575641
# Best model so far!
# Iteration: 1651, train loss: -9.130691602620534,
#                      test loss: -9.129583080388214
# Best model so far!
# Iteration: 1652, train loss: -9.130716438662034,
#                      test loss: -9.129605501024255
# Best model so far!
# Iteration: 1653, train loss: -9.130741244567337,
#                      test loss: -9.129627894533092
# Best model so far!
# Iteration: 1654, train loss: -9.130766020535251,
#                      test loss: -9.129650260963924
# Best model so far!
# Iteration: 1655, train loss: -9.130790766533606,
#                      test loss: -9.129672600365838
# Best model so far!
# Iteration: 1656, train loss: -9.13081548273187,
#                      test loss: -9.129694912787796
# Best model so far!
# Iteration: 1657, train loss: -9.130840169068895,
#                      test loss: -9.12971719827865
# Best model so far!
# Iteration: 1658, train loss: -9.130864825656225,
#                      test loss: -9.129739456887124
# Best model so far!
# Iteration: 1659, train loss: -9.130889452518918,
#                      test loss: -9.129761688661834
# Best model so far!
# Iteration: 1660, train loss: -9.130914049624517,
#                      test loss: -9.129783893651274
# Best model so far!
# Iteration: 1661, train loss: -9.130938617256428,
#                      test loss: -9.129806071903818
# Best model so far!
# Iteration: 1662, train loss: -9.13096315518095,
#                      test loss: -9.129828223467733
# Best model so far!
# Iteration: 1663, train loss: -9.130987663652386,
#                      test loss: -9.129850348391162
# Best model so far!
# Iteration: 1664, train loss: -9.131012142723836,
#                      test loss: -9.129872446722135
# Best model so far!
# Iteration: 1665, train loss: -9.131036592305081,
#                      test loss: -9.129894518508568
# Best model so far!
# Iteration: 1666, train loss: -9.131061012592331,
#                      test loss: -9.129916563798256
# Best model so far!
# Iteration: 1667, train loss: -9.131085403638306,
#                      test loss: -9.129938582638887
# Best model so far!
# Iteration: 1668, train loss: -9.13110976543842,
#                      test loss: -9.129960575078032
# Best model so far!
# Iteration: 1669, train loss: -9.131134097816684,
#                      test loss: -9.129982541163143
# Best model so far!
# Iteration: 1670, train loss: -9.131158401168587,
#                      test loss: -9.130004480941567
# Best model so far!
# Iteration: 1671, train loss: -9.131182675489171,
#                      test loss: -9.13002639446053
# Best model so far!
# Iteration: 1672, train loss: -9.131206920773485,
#                      test loss: -9.130048281767152
# Best model so far!
# Iteration: 1673, train loss: -9.131231137073598,
#                      test loss: -9.130070142908433
# Best model so far!
# Iteration: 1674, train loss: -9.131255324583877,
#                      test loss: -9.130091977931265
# Best model so far!
# Iteration: 1675, train loss: -9.131279483014273,
#                      test loss: -9.13011378688243
# Best model so far!
# Iteration: 1676, train loss: -9.131303612701345,
#                      test loss: -9.13013556980859
# Best model so far!
# Iteration: 1677, train loss: -9.131327713497475,
#                      test loss: -9.130157326756308
# Best model so far!
# Iteration: 1678, train loss: -9.1313517855964,
#                      test loss: -9.130179057772025
# Best model so far!
# Iteration: 1679, train loss: -9.131375829077799,
#                      test loss: -9.130200762902078
# Best model so far!
# Iteration: 1680, train loss: -9.131399843879239,
#                      test loss: -9.130222442192691
# Best model so far!
# Iteration: 1681, train loss: -9.131423830193734,
#                      test loss: -9.130244095689976
# Best model so far!
# Iteration: 1682, train loss: -9.131447787930348,
#                      test loss: -9.13026572343994
# Best model so far!
# Iteration: 1683, train loss: -9.131471717310019,
#                      test loss: -9.13028732548848
# Best model so far!
# Iteration: 1684, train loss: -9.131495618128419,
#                      test loss: -9.13030890188138
# Best model so far!
# Iteration: 1685, train loss: -9.131519490606193,
#                      test loss: -9.130330452664316
# Best model so far!
# Iteration: 1686, train loss: -9.131543334737207,
#                      test loss: -9.13035197788286
# Best model so far!
# Iteration: 1687, train loss: -9.13156715068493,
#                      test loss: -9.130373477582474
# Best model so far!
# Iteration: 1688, train loss: -9.131590938442955,
#                      test loss: -9.130394951808508
# Best model so far!
# Iteration: 1689, train loss: -9.131614698004887,
#                      test loss: -9.130416400606213
# Best model so far!
# Iteration: 1690, train loss: -9.131638429505426,
#                      test loss: -9.130437824020724
# Best model so far!
# Iteration: 1691, train loss: -9.131662132740566,
#                      test loss: -9.130459222097075
# Best model so far!
# Iteration: 1692, train loss: -9.131685808042244,
#                      test loss: -9.130480594880192
# Best model so far!
# Iteration: 1693, train loss: -9.131709455403627,
#                      test loss: -9.130501942414893
# Best model so far!
# Iteration: 1694, train loss: -9.131733074874195,
#                      test loss: -9.130523264745895
# Best model so far!
# Iteration: 1695, train loss: -9.13175666644705,
#                      test loss: -9.130544561917803
# Best model so far!
# Iteration: 1696, train loss: -9.131780230087191,
#                      test loss: -9.13056583397512
# Best model so far!
# Iteration: 1697, train loss: -9.131803765956397,
#                      test loss: -9.130587080962249
# Best model so far!
# Iteration: 1698, train loss: -9.131827274216059,
#                      test loss: -9.130608302923479
# Best model so far!
# Iteration: 1699, train loss: -9.131850754690404,
#                      test loss: -9.130629499903
# Best model so far!
# Iteration: 1700, train loss: -9.131874207652858,
#                      test loss: -9.130650671944899
# Best model so far!
# Iteration: 1701, train loss: -9.131897633039813,
#                      test loss: -9.130671819093156
# Best model so far!
# Iteration: 1702, train loss: -9.131921030955906,
#                      test loss: -9.13069294139165
# Best model so far!
# Iteration: 1703, train loss: -9.131944401253532,
#                      test loss: -9.130714038884157
# Best model so far!
# Iteration: 1704, train loss: -9.131967744149215,
#                      test loss: -9.130735111614348
# Best model so far!
# Iteration: 1705, train loss: -9.131991059635233,
#                      test loss: -9.130756159625795
# Best model so far!
# Iteration: 1706, train loss: -9.13201434773184,
#                      test loss: -9.130777182961964
# Best model so far!
# Iteration: 1707, train loss: -9.132037608598903,
#                      test loss: -9.130798181666222
# Best model so far!
# Iteration: 1708, train loss: -9.132060842256339,
#                      test loss: -9.130819155781833
# Best model so far!
# Iteration: 1709, train loss: -9.132084048779806,
#                      test loss: -9.130840105351961
# Best model so far!
# Iteration: 1710, train loss: -9.13210722799383,
#                      test loss: -9.130861030419668
# Best model so far!
# Iteration: 1711, train loss: -9.132130380224982,
#                      test loss: -9.130881931027915
# Best model so far!
# Iteration: 1712, train loss: -9.132153505520545,
#                      test loss: -9.130902807219563
# Best model so far!
# Iteration: 1713, train loss: -9.132176603788512,
#                      test loss: -9.130923659037375
# Best model so far!
# Iteration: 1714, train loss: -9.132199674964907,
#                      test loss: -9.13094448652401
# Best model so far!
# Iteration: 1715, train loss: -9.132222719402963,
#                      test loss: -9.130965289722031
# Best model so far!
# Iteration: 1716, train loss: -9.132245736815973,
#                      test loss: -9.1309860686739
# Best model so far!
# Iteration: 1717, train loss: -9.132268727473328,
#                      test loss: -9.131006823421982
# Best model so far!
# Iteration: 1718, train loss: -9.132291691505015,
#                      test loss: -9.131027554008542
# Best model so far!
# Iteration: 1719, train loss: -9.132314628680113,
#                      test loss: -9.131048260475744
# Best model so far!
# Iteration: 1720, train loss: -9.132337539211798,
#                      test loss: -9.13106894286566
# Best model so far!
# Iteration: 1721, train loss: -9.132360423091104,
#                      test loss: -9.131089601220259
# Best model so far!
# Iteration: 1722, train loss: -9.132383280475224,
#                      test loss: -9.131110235581415
# Best model so far!
# Iteration: 1723, train loss: -9.132406111299593,
#                      test loss: -9.131130845990903
# Best model so far!
# Iteration: 1724, train loss: -9.13242891555511,
#                      test loss: -9.131151432490404
# Best model so far!
# Iteration: 1725, train loss: -9.13245169345384,
#                      test loss: -9.1311719951215
# Best model so far!
# Iteration: 1726, train loss: -9.132474444958712,
#                      test loss: -9.131192533925676
# Best model so far!
# Iteration: 1727, train loss: -9.132497170143186,
#                      test loss: -9.131213048944325
# Best model so far!
# Iteration: 1728, train loss: -9.132519868914985,
#                      test loss: -9.131233540218737
# Best model so far!
# Iteration: 1729, train loss: -9.13254254145783,
#                      test loss: -9.131254007790115
# Best model so far!
# Iteration: 1730, train loss: -9.132565187789645,
#                      test loss: -9.13127445169956
# Best model so far!
# Iteration: 1731, train loss: -9.132587807955852,
#                      test loss: -9.131294871988082
# Best model so far!
# Iteration: 1732, train loss: -9.132610402084369,
#                      test loss: -9.131315268696593
# Best model so far!
# Iteration: 1733, train loss: -9.132632969945117,
#                      test loss: -9.131335641865915
# Best model so far!
# Iteration: 1734, train loss: -9.132655511913534,
#                      test loss: -9.13135599153677
# Best model so far!
# Iteration: 1735, train loss: -9.13267802786949,
#                      test loss: -9.131376317749792
# Best model so far!
# Iteration: 1736, train loss: -9.132700517940338,
#                      test loss: -9.13139662054552
# Best model so far!
# Iteration: 1737, train loss: -9.132722981978626,
#                      test loss: -9.131416899964394
# Best model so far!
# Iteration: 1738, train loss: -9.132745420193901,
# ...
#                      test loss: -9.145285192129917
# Best model so far!
# Iteration: 2867, train loss: -9.148093567545992,
#                      test loss: -9.145292634326987
# Best model so far!
# Iteration: 2868, train loss: -9.148101805735655,
#                      test loss: -9.14530007133424
# Best model so far!
# Iteration: 2869, train loss: -9.148110038199036,
#                      test loss: -9.145307503157104
# Best model so far!
# Iteration: 2870, train loss: -9.148118264942125,
#                      test loss: -9.145314929800998
# Best model so far!
# Iteration: 2871, train loss: -9.148126485987506,
#                      test loss: -9.145322351271332
# Best model so far!
# Iteration: 2872, train loss: -9.148134701307924,
#                      test loss: -9.14532976757351
# Best model so far!
# Iteration: 2873, train loss: -9.14814291084297,
#                      test loss: -9.145337178712932
# Best model so far!
# Iteration: 2874, train loss: -9.148151114698232,
#                      test loss: -9.145344584694984
# Best model so far!
# Iteration: 2875, train loss: -9.148159312763536,
#                      test loss: -9.145351985525048
# Best model so far!
# Iteration: 2876, train loss: -9.148167505194138,
#                      test loss: -9.145359381208499
# Best model so far!
# Iteration: 2877, train loss: -9.1481756918799,
#                      test loss: -9.145366771750703
# Best model so far!
# Iteration: 2878, train loss: -9.14818387289308,
#                      test loss: -9.14537415715702
# Best model so far!
# Iteration: 2879, train loss: -9.148192048223027,
#                      test loss: -9.145381537432801
# Best model so far!
# Iteration: 2880, train loss: -9.148200217925332,
#                      test loss: -9.14538891258339
# Best model so far!
# Iteration: 2881, train loss: -9.148208381873447,
#                      test loss: -9.145396282614126
# Best model so far!
# Iteration: 2882, train loss: -9.148216540271905,
#                      test loss: -9.145403647530335
# Best model so far!
# Iteration: 2883, train loss: -9.148224693027245,
#                      test loss: -9.145411007337342
# Best model so far!
# Iteration: 2884, train loss: -9.148232840013064,
#                      test loss: -9.145418362040461
# Best model so far!
# Iteration: 2885, train loss: -9.148240981384115,
#                      test loss: -9.145425711644997
# Best model so far!
# Iteration: 2886, train loss: -9.148249117162758,
#                      test loss: -9.145433056156254
# Best model so far!
# Iteration: 2887, train loss: -9.148257247206152,
#                      test loss: -9.145440395579522
# Best model so far!
# Iteration: 2888, train loss: -9.148265371685367,
#                      test loss: -9.145447729920086
# Best model so far!
# Iteration: 2889, train loss: -9.148273490523653,
#                      test loss: -9.145455059183226
# Best model so far!
# Iteration: 2890, train loss: -9.148281603825865,
#                      test loss: -9.14546238337421
# Best model so far!
# Iteration: 2891, train loss: -9.148289711498782,
#                      test loss: -9.145469702498305
# Best model so far!
# Iteration: 2892, train loss: -9.148297813581221,
#                      test loss: -9.145477016560765
# Best model so far!
# Iteration: 2893, train loss: -9.148305909980087,
#                      test loss: -9.145484325566837
# Best model so far!
# Iteration: 2894, train loss: -9.148314000783651,
#                      test loss: -9.145491629521766
# Best model so far!
# Iteration: 2895, train loss: -9.148322085931829,
#                      test loss: -9.145498928430785
# Best model so far!
# Iteration: 2896, train loss: -9.148330165578669,
#                      test loss: -9.14550622229912
# Best model so far!
# Iteration: 2897, train loss: -9.148338239647568,
#                      test loss: -9.145513511131993
# Best model so far!
# Iteration: 2898, train loss: -9.148346308160756,
#                      test loss: -9.145520794934614
# Best model so far!
# Iteration: 2899, train loss: -9.148354371074634,
#                      test loss: -9.14552807371219
# Best model so far!
# Iteration: 2900, train loss: -9.14836242847721,
#                      test loss: -9.145535347469922
# Best model so far!
# Iteration: 2901, train loss: -9.148370480292,
#                      test loss: -9.145542616212996
# Best model so far!
# Iteration: 2902, train loss: -9.148378526541208,
#                      test loss: -9.1455498799466
# Best model so far!
# Iteration: 2903, train loss: -9.148386567279866,
#                      test loss: -9.14555713867591
# Best model so far!
# Iteration: 2904, train loss: -9.148394602497243,
#                      test loss: -9.145564392406094
# Best model so far!
# Iteration: 2905, train loss: -9.148402632149802,
#                      test loss: -9.145571641142315
# Best model so far!
# Iteration: 2906, train loss: -9.148410656276102,
#                      test loss: -9.14557888488973
# Best model so far!
# Iteration: 2907, train loss: -9.148418674849042,
#                      test loss: -9.145586123653487
# Best model so far!
# Iteration: 2908, train loss: -9.14842668793994,
#                      test loss: -9.145593357438726
# Best model so far!
# Iteration: 2909, train loss: -9.148434695505273,
#                      test loss: -9.145600586250584
# Best model so far!
# Iteration: 2910, train loss: -9.148442697567125,
#                      test loss: -9.145607810094184
# Best model so far!
# Iteration: 2911, train loss: -9.148450694098408,
#                      test loss: -9.14561502897465
# Best model so far!
# Iteration: 2912, train loss: -9.14845868521944,
#                      test loss: -9.145622242897094
# Best model so far!
# Iteration: 2913, train loss: -9.148466670821213,
#                      test loss: -9.145629451866622
# Best model so far!
# Iteration: 2914, train loss: -9.148474650958494,
#                      test loss: -9.145636655888332
# Best model so far!
# Iteration: 2915, train loss: -9.14848262557148,
#                      test loss: -9.145643854967316
# Best model so far!
# Iteration: 2916, train loss: -9.14849059471491,
#                      test loss: -9.145651049108663
# Best model so far!
# Iteration: 2917, train loss: -9.14849855844345,
#                      test loss: -9.145658238317445
# Best model so far!
# Iteration: 2918, train loss: -9.1485065166973,
#                      test loss: -9.14566542259874
# Best model so far!
# Iteration: 2919, train loss: -9.148514469498425,
#                      test loss: -9.145672601957605
# Best model so far!
# Iteration: 2920, train loss: -9.148522416885084,
#                      test loss: -9.145679776399103
# Best model so far!
# Iteration: 2921, train loss: -9.14853035886284,
#                      test loss: -9.145686945928281
# Best model so far!
# Iteration: 2922, train loss: -9.148538295306698,
#                      test loss: -9.145694110550185
# Best model so far!
# Iteration: 2923, train loss: -9.1485462263039,
#                      test loss: -9.14570127026985
# Best model so far!
# Iteration: 2924, train loss: -9.148554151908959,
#                      test loss: -9.145708425092305
# Best model so far!
# Iteration: 2925, train loss: -9.148562072127405,
#                      test loss: -9.145715575022574
# Best model so far!
# Iteration: 2926, train loss: -9.14856998691587,
#                      test loss: -9.145722720065674
# Best model so far!
# Iteration: 2927, train loss: -9.148577896279923,
#                      test loss: -9.145729860226613
# Best model so far!
# Iteration: 2928, train loss: -9.148585800257688,
#                      test loss: -9.14573699551039
# Best model so far!
# Iteration: 2929, train loss: -9.148593698805847,
#                      test loss: -9.145744125922006
# Best model so far!
# Iteration: 2930, train loss: -9.148601591978778,
#                      test loss: -9.145751251466445
# Best model so far!
# Iteration: 2931, train loss: -9.148609479765717,
#                      test loss: -9.145758372148691
# Best model so far!
# Iteration: 2932, train loss: -9.148617362172173,
#                      test loss: -9.14576548797372
# Best model so far!
# Iteration: 2933, train loss: -9.148625239203652,
#                      test loss: -9.145772598946497
# Best model so far!
# Iteration: 2934, train loss: -9.148633110849394,
#                      test loss: -9.145779705071986
# Best model so far!
# Iteration: 2935, train loss: -9.148640977147398,
#                      test loss: -9.14578680635514
# Best model so far!
# Iteration: 2936, train loss: -9.148648838135614,
#                      test loss: -9.145793902800909
# Best model so far!
# Iteration: 2937, train loss: -9.148656693803227,
#                      test loss: -9.14580099441423
# Best model so far!
# Iteration: 2938, train loss: -9.14866454394468,
#                      test loss: -9.145808081200043
# Best model so far!
# Iteration: 2939, train loss: -9.14867238887388,
#                      test loss: -9.145815163163272
# Best model so far!
# Iteration: 2940, train loss: -9.148680228482611,
#                      test loss: -9.14582224030884
# Best model so far!
# Iteration: 2941, train loss: -9.14868806276009,
#                      test loss: -9.14582931264166
# Best model so far!
# Iteration: 2942, train loss: -9.148695891695544,
#                      test loss: -9.145836380166639
# Best model so far!
# Iteration: 2943, train loss: -9.148703715213404,
#                      test loss: -9.145843442888678
# Best model so far!
# Iteration: 2944, train loss: -9.148711533464967,
#                      test loss: -9.145850500812672
# Best model so far!
# Iteration: 2945, train loss: -9.148719346439403,
#                      test loss: -9.145857553943511
# Best model so far!
# Iteration: 2946, train loss: -9.148727154109714,
#                      test loss: -9.145864602286073
# Best model so far!
# Iteration: 2947, train loss: -9.148734956497483,
#                      test loss: -9.145871645845233
# Best model so far!
# Iteration: 2948, train loss: -9.148742753575734,
#                      test loss: -9.145878684625858
# Best model so far!
# Iteration: 2949, train loss: -9.148750545414545,
#                      test loss: -9.145885718632812
# Best model so far!
# Iteration: 2950, train loss: -9.148758331938426,
#                      test loss: -9.145892747870946
# Best model so far!
# Iteration: 2951, train loss: -9.148766113185097,
#                      test loss: -9.14589977234511
# Best model so far!
# Iteration: 2952, train loss: -9.148773889176072,
#                      test loss: -9.145906792060147
# Best model so far!
# Iteration: 2953, train loss: -9.148781659916693,
#                      test loss: -9.145913807020888
# Best model so far!
# Iteration: 2954, train loss: -9.148789425331582,
#                      test loss: -9.145920817232165
# Best model so far!
# Iteration: 2955, train loss: -9.148797185539099,
#                      test loss: -9.145927822698797
# Best model so far!
# Iteration: 2956, train loss: -9.148804940496138,
#                      test loss: -9.1459348234256
# Best model so far!
# Iteration: 2957, train loss: -9.1488126901919,
#                      test loss: -9.145941819417384
# Best model so far!
# Iteration: 2958, train loss: -9.148820434599479,
#                      test loss: -9.14594881067895
# Best model so far!
# Iteration: 2959, train loss: -9.148828173788697,
#                      test loss: -9.145955797215095
# Best model so far!
# Iteration: 2960, train loss: -9.148835907780953,
#                      test loss: -9.145962779030606
# Best model so far!
# Iteration: 2961, train loss: -9.148843636549302,
#                      test loss: -9.145969756130269
# Best model so far!
# Iteration: 2962, train loss: -9.148851360034643,
#                      test loss: -9.145976728518857
# Best model so far!
# Iteration: 2963, train loss: -9.148859078274509,
#                      test loss: -9.145983696201142
# Best model so far!
# Iteration: 2964, train loss: -9.148866791370738,
#                      test loss: -9.145990659181889
# Best model so far!
# Iteration: 2965, train loss: -9.148874499264203,
#                      test loss: -9.14599761746585
# Best model so far!
# Iteration: 2966, train loss: -9.148882201992322,
#                      test loss: -9.14600457105778
# Best model so far!
# Iteration: 2967, train loss: -9.148889899544244,
#                      test loss: -9.146011519962423
# Best model so far!
# Iteration: 2968, train loss: -9.14889759194127,
#                      test loss: -9.146018464184515
# Best model so far!
# Iteration: 2969, train loss: -9.14890527904406,
#                      test loss: -9.146025403728787
# Best model so far!
# Iteration: 2970, train loss: -9.148912961050627,
#                      test loss: -9.146032338599966
# Best model so far!
# Iteration: 2971, train loss: -9.148920637821668,
#                      test loss: -9.14603926880277
# Best model so far!
# Iteration: 2972, train loss: -9.148928309474776,
#                      test loss: -9.146046194341912
# Best model so far!
# Iteration: 2973, train loss: -9.148935975967003,
#                      test loss: -9.146053115222095
# Best model so far!
# Iteration: 2974, train loss: -9.148943637287518,
#                      test loss: -9.146060031448023
# Best model so far!
# Iteration: 2975, train loss: -9.148951293489622,
#                      test loss: -9.146066943024387
# Best model so far!
# Iteration: 2976, train loss: -9.148958944546429,
#                      test loss: -9.146073849955874
# Best model so far!
# Iteration: 2977, train loss: -9.148966590431089,
#                      test loss: -9.146080752247165
# Best model so far!
# Iteration: 2978, train loss: -9.148974231148813,
#                      test loss: -9.146087649902936
# Best model so far!
# Iteration: 2979, train loss: -9.148981866848862,
#                      test loss: -9.146094542927852
# Best model so far!
# Iteration: 2980, train loss: -9.148989497296272,
#                      test loss: -9.146101431326578
# Best model so far!
# Iteration: 2981, train loss: -9.148997122656285,
#                      test loss: -9.146108315103769
# Best model so far!
# Iteration: 2982, train loss: -9.14900474293402,
#                      test loss: -9.146115194264071
# Best model so far!
# Iteration: 2983, train loss: -9.149012358150573,
#                      test loss: -9.146122068812133
# Best model so far!
# Iteration: 2984, train loss: -9.149019968199177,
#                      test loss: -9.146128938752588
# Best model so far!
# Iteration: 2985, train loss: -9.149027573164892,
#                      test loss: -9.146135804090068
# Best model so far!
# Iteration: 2986, train loss: -9.149035173020891,
#                      test loss: -9.146142664829197
# Best model so far!
# Iteration: 2987, train loss: -9.149042767852125,
#                      test loss: -9.146149520974594
# Best model so far!
# Iteration: 2988, train loss: -9.14905035752001,
#                      test loss: -9.146156372530871
# Best model so far!
# Iteration: 2989, train loss: -9.149057942077592,
#                      test loss: -9.146163219502634
# Best model so far!
# Iteration: 2990, train loss: -9.14906552162568,
#                      test loss: -9.146170061894484
# Best model so far!
# Iteration: 2991, train loss: -9.149073096073648,
#                      test loss: -9.146176899711012
# Best model so far!
# Iteration: 2992, train loss: -9.149080665490356,
#                      test loss: -9.146183732956807
# Best model so far!
# Iteration: 2993, train loss: -9.149088229785256,
#                      test loss: -9.14619056163645
# Best model so far!
# Iteration: 2994, train loss: -9.149095789090893,
#                      test loss: -9.146197385754519
# Best model so far!
# Iteration: 2995, train loss: -9.149103343332659,
#                      test loss: -9.146204205315579
# Best model so far!
# Iteration: 2996, train loss: -9.149110892579287,
#                      test loss: -9.146211020324195
# Best model so far!
# Iteration: 2997, train loss: -9.149118436708493,
#                      test loss: -9.146217830784925
# Best model so far!
# Iteration: 2998, train loss: -9.149125975852641,
#                      test loss: -9.146224636702318
# Best model so far!
# Iteration: 2999, train loss: -9.149133510016716,
#                      test loss: -9.146231438080921
# Best model so far!
# Iteration: 3000, train loss: -9.149141039030859,
#                      test loss: -9.14623823492527
# Best model so far!

# %% [markdown]
# ## Environment Drift Detection
# ### Load Trained SVGP StatePredictor

# %%
class StatePredictor(ApproximateGP):
  def __init__(self, inducing_points):
    inducing_points = inducing_points
    variational_distribution = CholeskyVariationalDistribution(inducing_points.size(-2),
                                                               batch_shape=torch.Size([n_tasks]))

    variational_strategy = gpytorch.variational.IndependentMultitaskVariationalStrategy(
                                                   VariationalStrategy(self, inducing_points,
                                                       variational_distribution,
                                                       learn_inducing_locations=True),
                                                num_tasks=n_tasks
                                             )

    super(StatePredictor, self).__init__(variational_strategy)
    self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([n_tasks]))
    self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel(batch_shape=torch.Size([n_tasks]),
                                                                                ard_num_dims=X_train_env0_tensor.size(-1)),
                                                    batch_shape = torch.Size([n_tasks])
                                                  )

  def forward(self, x):
    mean_x = self.mean_module(x)
    covar_x = self.covar_module(x)
    return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# Load the scaler
import pickle

with open('scaler.pkl', 'rb') as f:
    scaler = pickle.load(f)

# Load the GP model
model_gp_env0 = torch.load("model_gp_env0.pth")

# %% [markdown]
# ### Simulation

# %%
with torch.no_grad():

  env1_step = 3000
  env2_step = 3000

  total_step = env1_step + env2_step

  compute_mse_steps = 100

  obs_true = deque([], maxlen=compute_mse_steps)
  obs_predicted = deque([], maxlen=compute_mse_steps)


  n_past_steps_to_store = 500
  replay_buffer = deque([], maxlen=n_past_steps_to_store)

  mses_production = []


  env1 = gym.make("Pendulum-v1", g=10.0) # Same as the original env
  env2 = gym.make("Pendulum-v1", g=10.5) # Drifted Environment with different gravity


  env_current = env1
  obs_t, _ = env_current.reset() # Initialize the environment

  for t in range(1, total_step+1):

    if t%500 == 0:
     print(f"step {t}")

    action_t, _state = model.predict(obs_t, deterministic=True)
    obs_tplus1, r_tplus1, terminated, truncated, info = env_current.step(action_t)
    replay_buffer.append([obs_t, action_t, obs_tplus1, r_tplus1, t])

    x = np.concatenate([obs_t, action_t]).reshape(1,-1)
    x = scaler.transform(x)
    x = torch.from_numpy(x)
    x = x.to(device)

    y = obs_tplus1-obs_t

    y_predicted = model_gp_env0(x)



    mses_production.append(mse(y, y_predicted.mean.flatten().detach().cpu().numpy()))


    done = terminated or truncated

    obs_t = obs_tplus1

    if done:
      obs_t, _ = env_current.reset()

    if t==env1_step: ## Environment Drift Happens
      env_current = env2
      obs_t, _ = env_current.reset()
# Out:
# step 500
# step 1000
# step 1500
# step 2000
# step 2500
# step 3000
# step 3500
# step 4000
# step 4500
# step 5000
# step 5500
# step 6000

# %%
plt.plot(np.array(mses_production))
#plt.axvline(x=3000, label="Environment Drift", color='red')
plt.xlabel("step")
plt.ylabel("MSE")
plt.xticks(np.arange(0,6001, 250), rotation=70)
#plt.legend()
plt.title("SAC Pendulum")
plt.show()

# %% [markdown]
# ### Environment Drift Detection with Prob-CUSUM

# %%
class CusumMeanDetector():
  def __init__(self, mu_ref, sigma_ref, obs_ref, p_limit=0.01) -> None:
    self._mu_ref = mu_ref
    self._sigma_ref = sigma_ref
    self._p_limit = p_limit

    self._reset(obs_ref)

  def _reset(self, obs_ref) -> None:
    self.current_t = len(obs_ref)
    self.current_obs = obs_ref.copy()
    #self.mu_current = self._mu_ref
    #self.sigma_current = self._sigma_ref

  def _update_data(self, y:float) -> None:
    self.current_t += 1
    self.current_obs.append(y)

  def _get_pvalue(self, y, alternative="two-sided") -> float:
    assert alternative in {"two-sided", "greater", "less"}
    pcum = scipy.stats.norm.cdf(y, loc=0., scale=1.)
    if alternative == "two-sided":
      p = 2*(1-pcum)
    if alternative == "greater":
      p = 1-pcum
    if alternative == "less":
      p = pcum
    return p

  def _check_for_changepoint(self, alternative) -> Tuple[float, bool]:
    standardized_sum = np.sum(np.array(self.current_obs)-self._mu_ref)/(self._sigma_ref*self.current_t**0.5)
    p = self._get_pvalue(standardized_sum, alternative)
    return p, p < self._p_limit


  def predict_next(self, y, alternative="two-sided") -> Tuple[float, bool]:
    self._update_data(y)
    p, is_changepoint = self._check_for_changepoint(alternative)
    return p, is_changepoint

# %%
# Environment Drift Detection with CUSUM
env0_steps = 4000
window_size = 200
mses_reference = []
p_limit = 0.05
obs_t, _ = env0.reset()
for t in range(env0_steps):
  action_t, _state = model.predict(obs_t, deterministic=True)
  obs_tplus1, r_tplus1, terminated, truncated, info = env0.step(action_t)
  #x = np.concatenate([obs_t, obs_tplus1-obs_t]).reshape(1,-1)
  #x = scaler.transform(x)
  #x = torch.from_numpy(x.astype("float32")).to(device)
  #action_t_pre = model_gp_env0(x)
  x = np.concatenate([obs_t,action_t]).reshape(1,-1)
  x = scaler.transform(x)
  x = torch.from_numpy(x)
  x = x.to(device)

  y = obs_tplus1-obs_t

  with torch.no_grad():
    y_predicted = model_gp_env0(x)



  mses_reference.append(mse(y, y_predicted.mean.flatten().detach().cpu().numpy()))

  done = terminated or truncated
  obs_t = obs_tplus1
  if done:
    obs_t, _ = env0.reset()

#print(f"Reference mean: {np.mean(mses_reference)}, Reference std: {np.std(mses_reference)}")

mu_ref = np.mean(mses_reference)
sigma_ref = np.std(mses_reference, ddof=1)
mses_reference_window = np.random.choice(mses_reference, size=window_size, replace=False).tolist()

drift_detector = CusumMeanDetector(mu_ref=mu_ref,
                                   sigma_ref = sigma_ref,
                                   obs_ref=mses_reference_window,
                                   p_limit = p_limit)


false_alarms = 0
delay = 4000

for i,val in enumerate(mses_production):
  #drift_detector.add_data_point(val)
  p_value, drift_detected = drift_detector.predict_next(val, alternative="greater")
  if drift_detected:
    print(f"Drift Detected at: {i} with value: {val}")
    mses_reference_window = np.random.choice(mses_reference, size=window_size, replace=False).tolist()
    drift_detector._reset(mses_reference_window)
    if i<3000:
      false_alarms+=1
    if i >= 3000:
      delay = i-3000
      break

print(f"False Alarms: {false_alarms}, Delay: {delay}")
# Out:
# Drift Detected at: 3000 with value: 0.0003837704425677657
# False Alarms: 0, Delay: 0

# %% [markdown]
# ### Page-Hinkely CUSUM

# %%
ph = drift.PageHinkley(mode="up", delta=0.005)

env0_steps = 4000
#window_size = 200
mses_reference = []
p_limit = 0.05
obs_t, _ = env0.reset()
for t in range(env0_steps):
  action_t, _state = model.predict(obs_t, deterministic=True)
  obs_tplus1, r_tplus1, terminated, truncated, info = env0.step(action_t)
  #x = np.concatenate([obs_t, obs_tplus1-obs_t]).reshape(1,-1)
  #x = scaler.transform(x)
  #x = torch.from_numpy(x.astype("float32")).to(device)
  #action_t_pre = model_gp_env0(x)
  x = np.concatenate([obs_t,action_t]).reshape(1,-1)
  x = scaler.transform(x)
  x = torch.from_numpy(x)
  x = x.to(device)

  y = obs_tplus1-obs_t

  with torch.no_grad():
    y_predicted = model_gp_env0(x)



  mses_reference.append(mse(y, y_predicted.mean.flatten().detach().cpu().numpy()))

  done = terminated or truncated
  obs_t = obs_tplus1
  if done:
    obs_t, _ = env0.reset()

#print(f"Reference mean: {np.mean(mses_reference)}, Reference std: {np.std(mses_reference)}")

mu_ref = np.mean(mses_reference)
sigma_ref = np.std(mses_reference, ddof=1)

mses_production_norm = (mses_production-mu_ref)/sigma_ref


false_alarms = 0
delay = 4000

for i, val in enumerate(mses_production_norm):
  ph.update(val)
  if ph.drift_detected and val>0:
    print(f"Change detected at index {i}, input value: {val}")
    if i<3000:
      false_alarms+=1
    if i>=3000:
      delay = i-3000
      break

print(f"False Alarms: {false_alarms}, Delay: {delay}")
# Out:
# Change detected at index 629, input value: 5.784019947052002
# Change detected at index 1631, input value: 2.708662271499634
# Change detected at index 2243, input value: 1.5721750259399414
# Change detected at index 2807, input value: 4.021366119384766
# Change detected at index 3000, input value: 208.3068389892578
# False Alarms: 4, Delay: 0

# %% [markdown]
# ### ADWIN

# %%
adwin = drift.ADWIN()

env0_steps = 4000
#window_size = 200
mses_reference = []
p_limit = 0.05
obs_t, _ = env0.reset()
for t in range(env0_steps):
  action_t, _state = model.predict(obs_t, deterministic=True)
  obs_tplus1, r_tplus1, terminated, truncated, info = env0.step(action_t)
  #x = np.concatenate([obs_t, obs_tplus1-obs_t]).reshape(1,-1)
  #x = scaler.transform(x)
  #x = torch.from_numpy(x.astype("float32")).to(device)
  #action_t_pre = model_gp_env0(x)
  x = np.concatenate([obs_t,action_t]).reshape(1,-1)
  x = scaler.transform(x)
  x = torch.from_numpy(x)
  x = x.to(device)

  y = obs_tplus1-obs_t

  with torch.no_grad():
    y_predicted = model_gp_env0(x)

  mses_reference.append(mse(y, y_predicted.mean.flatten().detach().cpu().numpy()))

  done = terminated or truncated
  obs_t = obs_tplus1
  if done:
    obs_t, _ = env0.reset()


mu_ref = np.mean(mses_reference)
sigma_ref = np.std(mses_reference, ddof=1)

mses_production_norm = (mses_production-mu_ref)/sigma_ref


false_alarms = 0
delay = 4000

for i, val in enumerate(mses_production_norm):
  adwin.update(val)
  if adwin.drift_detected and val>0:
    print(f"Change detected at index {i}, input value: {val}")
    if i<3000:
      false_alarms+=1
    if i>=3000:
      delay = i-3000
      break

print(f"False Alarms: {false_alarms}, Delay: {delay}")
# Out:
# Change detected at index 3039, input value: 0.04913200065493584
# False Alarms: 0, Delay: 39

# %% [markdown]
# ### KSWIN

# %%
kswin = drift.KSWIN()

env0_steps = 4000
mses_reference = []
obs_t, _ = env0.reset()
for t in range(env0_steps):
  action_t, _state = model.predict(obs_t, deterministic=True)
  obs_tplus1, r_tplus1, terminated, truncated, info = env0.step(action_t)
  #x = np.concatenate([obs_t, obs_tplus1-obs_t]).reshape(1,-1)
  #x = scaler.transform(x)
  #x = torch.from_numpy(x.astype("float32")).to(device)
  #action_t_pre = model_gp_env0(x)
  x = np.concatenate([obs_t,action_t]).reshape(1,-1)
  x = scaler.transform(x)
  x = torch.from_numpy(x)
  x = x.to(device)

  y = obs_tplus1-obs_t

  with torch.no_grad():
    y_predicted = model_gp_env0(x)

  mses_reference.append(mse(y, y_predicted.mean.flatten().detach().cpu().numpy()))

  done = terminated or truncated
  obs_t = obs_tplus1
  if done:
    obs_t, _ = env0.reset()


mu_ref = np.mean(mses_reference)
sigma_ref = np.std(mses_reference, ddof=1)

mses_production_norm = (mses_production-mu_ref)/sigma_ref


false_alarms = 0
delay = 4000

for i, val in enumerate(mses_production_norm):
  kswin.update(val)
  if kswin.drift_detected and val>0:
    print(f"Change detected at index {i}, input value: {val}")
    if i<3000:
      false_alarms+=1
    if i>=3000:
      delay = i-3000
      break

print(f"False Alarms: {false_alarms}, Delay: {delay}")
# Out:
# Change detected at index 408, input value: 0.33415156602859497
# Change detected at index 613, input value: 0.7331618666648865
# Change detected at index 813, input value: 1.0454833507537842
# Change detected at index 1013, input value: 0.4088887572288513
# Change detected at index 1413, input value: 0.14616765081882477
# Change detected at index 1613, input value: 0.4076729714870453
# Change detected at index 1813, input value: 0.9264419674873352
# Change detected at index 2013, input value: 0.4911957383155823
# Change detected at index 2213, input value: 0.09403865784406662
# Change detected at index 2613, input value: 0.01816585473716259
# Change detected at index 2813, input value: 12.83243179321289
# Change detected at index 3013, input value: 211.83822631835938
# False Alarms: 11, Delay: 13
